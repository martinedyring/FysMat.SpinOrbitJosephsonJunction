# %%
import sys
import numpy as np

sys.path.append("/Users/martinedh/Documents/NTNU/GitHub/FysMat/Masteroppgave")

# %%
# Cython code and own
# %load_ext Cython

# %%
# System
import io # file streaming
import time # date
#Plotting
from mpl_toolkits.mplot3d import Axes3D  
import matplotlib.pyplot as plt
from matplotlib import cm
import pylab
pylab.rcParams['figure.figsize'] = (15.0, 10.0)
# %matplotlib inline

# Cython code and own
#%%cython
#cimport cython
import current_phase_calculations
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-08cfad1aab3f> in <module>()
#      13 #%%cython
#      14 #cimport cython
# ---> 15 import current_phase_calculations
#
# ModuleNotFoundError: No module named 'current_phase_calculations'

# %%
from current_phase_calculations import solve_for_shms_system_phase
# Out:
# -----------------------------------------------------------------
# ModuleNotFoundError             Traceback (most recent call last)
# <ipython-input-4-0eaeda106f33> in <module>()
# ----> 1 from current_phase_calculations import solve_for_shms_system_phase
#
# ModuleNotFoundError: No module named 'current_phase_calculations'

# %%
current_for_phase, phase_arr = solve_for_shms_system_phase(alpha_array=[0,0,0.5], max_num_iter=np.inf, tol=1e-6, L_y=30, L_z=30, L_sc_0=10,L_soc=3,L_sc=10)
# Out:
# -----------------------------------------------------------------
# NameError                       Traceback (most recent call last)
# <ipython-input-8-fe75673c5c82> in <module>()
# ----> 1 current_for_phase, phase_arr = solve_for_shms_system_phase(alpha_array=[0,0,0.5], max_num_iter=np.inf, tol=1e-6, L_y=30, L_z=30, L_sc_0=10,L_soc=3,L_sc=10)
#
# NameError: name 'solve_for_shms_system_phase' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np
from current_phase_calculations import solve_for_shms_system_phase
# %matplotlib inline
# %load_ext Cython
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-fce06e1e7fcf> in <module>()
#       1 import matplotlib.pyplot as plt
#       2 import numpy as np
# ----> 3 from current_phase_calculations import solve_for_shms_system_phase
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#       5 get_ipython().run_line_magic('load_ext', 'Cython')
#
# ModuleNotFoundError: No module named 'current_phase_calculations'

# %%
# %%cython
# cimport bdgsolver
# from current_phase_calculations import solve_for_shms_system_phase

# %%
#https://numpy.org/doc/stable/reference/generated/numpy.savez.html
#np.savez('sns_eigen_test.npz', phase_arr, current_for_phase)
import numpy as np
import matplotlib.pyplot as plt

import sys

sys.path.append("/Users/martinedh/Documents/NTNU/GitHub/FysMat/Masteroppgave")
npzfile_current = np.load('shms_5_3_5_test.npz')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-fab5c6518525> in <module>()
#       7
#       8 sys.path.append("/Users/martinedh/Documents/NTNU/GitHub/FysMat/Masteroppgave")
# ----> 9 npzfile_current = np.load('shms_5_3_5_test.npz')
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     414             own_fid = False
#     415         else:
# --> 416             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     417             own_fid = True
#     418
#
# FileNotFoundError: [Errno 2] No such file or directory: 'shms_5_3_5_test.npz'

# %%
phase = npzfile_current['arr_0']
current = npzfile_current['arr_1']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d9ae4d2c9ee7> in <module>()
# ----> 1 phase = npzfile_current['arr_0']
#       2 current = npzfile_current['arr_1']
#
# NameError: name 'npzfile_current' is not defined

# %%
plt.plot(phase, np.real(current))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a99090a5d133> in <module>()
# ----> 1 plt.plot(phase, np.real(current))
#
# NameError: name 'phase' is not defined

# %%
#https://numpy.org/doc/stable/reference/generated/numpy.savez.html
#np.savez('sns_eigen_test.npz', phase_arr, current_for_phase)
import numpy as np

npzfile = np.load('sc_energies_test.npz')
#npzfile.files
#['arr_0', 'arr_1']
#npzfile['arr_0']

# %%
eigen= npzfile['arr_0']
#print(eigen)

# %%
import matplotlib.pyplot as plt

print(np.shape(eigen))

x = np.linspace(3,-3,29, endpoint=False)
for i in range(np.shape(eigen)[0]):
    plt.plot(np.flip(x), eigen[i,:,7], color='limegreen')
    plt.ylim(-4,4)
    plt.xlim(-3,3)
plt.show()
# Out:
# (200, 29, 29)

# %%
import numpy as np
import matplotlib.pyplot as plt

npzfile_fmatrix = np.load('sc_fmatrix_test.npz')

# %%
fmatrix = npzfile_fmatrix['arr_0']

# %%
x = np.linspace(1,30,50)
#plt.plot(x,np.imag(fmatrix))
plt.plot(x,np.real(fmatrix))

# %%
import sys

sys.path.append("/Users/martinedh/Documents/NTNU/GitHub/FysMat/Prosjektoppgave")
from plots import plot_density_of_states

# %%
#https://numpy.org/doc/stable/reference/generated/numpy.savez.html
#np.savez('sns_eigen_test.npz', phase_arr, current_for_phase)
import numpy as np

sys.path.append("/Users/martinedh/Documents/NTNU/GitHub/FysMat/Masteroppgave")
npzfile = np.load('sc_dos_test.npz')
#npzfile.files
#['arr_0', 'arr_1']
#npzfile['arr_0']

# %%
ldos = npzfile['arr_0']
energies = npzfile['arr_1']
#print(eigen)

# %%
plot_density_of_states(energies, ldos, L_sc_0 = 0, L_nc=10, L_sc=10, L_soc=0)
# Out:
# (120,)
# (15, 120)
# /Users/martinedh/Documents/NTNU/GitHub/FysMat/Prosjektoppgave/plots.py:75: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(es, np.sum(ldos[:L_sc_0], axis=0) / L_sc_0, label='LDOS in SC')
# /Users/martinedh/Documents/NTNU/GitHub/FysMat/Prosjektoppgave/plots.py:87: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(es, np.sum(ldos[L_sc_0+L_nc:L_sc_0+L_nc+L_soc], axis=0)/L_soc, label='LDOS in S0C')

# %%
print(3)
# Out:
# 3

# %%
print(np.linspace(-3,5,10, startpoint=False))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-0e5c582aed17> in <module>()
# ----> 1 print(np.linspace(-3,5,10, startpoint=False))
#
# <__array_function__ internals> in linspace(*args, **kwargs)
#
# TypeError: _linspace_dispatcher() got an unexpected keyword argument 'startpoint'

# %%
x = np.zeros((2,2), dtype=np.complex128)

# %%
print(x)
# Out:
# [[0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j]]

# %%
type(x)
# Out:
# numpy.ndarray

# %%
ky_array = np.linspace(-np.pi, np.pi, num=(15))

# %%
type(ky_array[0])
# Out:
# numpy.float64
