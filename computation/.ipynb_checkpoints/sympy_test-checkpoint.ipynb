# %% [markdown]
# <h3> determinant

# %%
from sympy import *
import numpy as np

# %%
u, v, rho_sigma, H, h_bar, k, m, m_bar, q, q_bar = symbols('u v rho_sigma H h_bar k m m_bar q q_bar')
L, phi = symbols('L phi')
a, b, c, d, alpha, beta, gamma, delta = symbols('a b c d alpha beta gamma delta')
x = symbols('x')

# %% [markdown]
# A = Matrix([[rho_sigma * v, u, 0, 0, -1, -e_pluss_q, 0, 0],
#             [u, rho_sigma * v, 0, 0, 0, 0, -e_minus_bq, -1],
#             [0, 0, -u*e_pluss_phi, -rho_sigma * v * e_pluss_phi, e_pluss_q, 1, 0, 0],
#             [0, 0, -rho_sigma * v * e_minus_phi, -u*e_minus_phi, 0, 0, 1, e_minus_bq],
#             [-rho_sigma * v * (2*H/h_bar**2 + I*k/m), -u * (2*H/h_bar**2 - I*k/m), 0, 0, I*q/bm, -I*q*e_pluss_q/bm, 0, 0],
#             [-u * (2*H/h_bar**2 + I*k/m), -rho_sigma * v * (2*H/h_bar**2 - I*k/m), 0, 0, 0, 0, I*q*e_minus_bq/bm, -I*bq/bm],
#             [0, 0, -u * e_pluss_phi * (2*H/h_bar**2 - I*k/m), -rho_sigma * v * e_pluss_phi * (2*H/h_bar**2 + I*k/m), -I*q*e_pluss_q/bm, I*q/bm, 0, 0],
#             [0, 0, -rho_sigma * v * e_minus_phi * (2*H/h_bar**2 - I*k/m), -u * e_minus_phi * (2*H/h_bar**2 + I*k/m), 0, 0, -I*bq/bm, I*bq*e_pluss_bq/bm]
#            ])

# %%
A = Matrix([[rho_sigma * v, u, 0, 0, -1, -exp(I*q*L), 0, 0],
            [u, rho_sigma * v, 0, 0, 0, 0, -exp(-I*q_bar*L), -1],
            [0, 0, -u*exp(I*phi/2), -rho_sigma * v * exp(I*phi/2), exp(I*q*L), 1, 0, 0],
            [0, 0, -rho_sigma * v * exp(-I*phi/2), -u*exp(-I*phi/2), 0, 0, 1, exp(-I*q_bar*L)],
            [-rho_sigma * v * (2*H/h_bar**2 + I*k/m), -u * (2*H/h_bar**2 - I*k/m), 0, 0, I*q/m_bar, -I*q*exp(I*q*L)/m_bar, 0, 0],
            [-u * (2*H/h_bar**2 + I*k/m), -rho_sigma * v * (2*H/h_bar**2 - I*k/m), 0, 0, 0, 0, I*q_bar*exp(-I*q_bar*L)/m_bar, -I*q_bar/m_bar],
            [0, 0, -u * exp(I*phi/2) * (2*H/h_bar**2 - I*k/m), -rho_sigma * v * exp(I*phi/2) * (2*H/h_bar**2 + I*k/m), -I*q*exp(I*q*L)/m_bar, I*q/m_bar, 0, 0],
            [0, 0, -rho_sigma * v * exp(-I*phi/2) * (2*H/h_bar**2 - I*k/m), -u * exp(-I*phi/2) * (2*H/h_bar**2 + I*k/m), 0, 0, -I*q_bar/m_bar, I*q_bar*exp(I*q_bar*L)/m_bar]
           ])
#ImmutableMatrix

# %%
x = Matrix([a, b, c, d, alpha, beta, gamma, delta])
sol = ImmutableMatrix([0, 0, 0, 0, 0, 0, 0, 0])

# %%
A
# Out:
# Matrix([
# [                        rho_sigma*v,                                   u,                                                 0,                                                0,                    -1,           -exp(I*L*q),                             0,                            0],
# [                                  u,                         rho_sigma*v,                                                 0,                                                0,                     0,                     0,              -exp(-I*L*q_bar),                           -1],
# [                                  0,                                   0,                                   -u*exp(I*phi/2),                        -rho_sigma*v*exp(I*phi/2),            exp(I*L*q),                     1,                             0,                            0],
# ...

# %%
determinant = np.load('determinant.npz')

# %%
determinant

# %%
tmp = (-64*H**6*m**6*m_bar**5*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 64*H**6*m**6*m_bar**5*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q) + 64*H**6*m**6*m_bar**5*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) - 64*H**6*m**6*m_bar**5*rho_sigma**8*v**8*exp(I*phi) + 256*H**6*m**6*m_bar**5*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 256*H**6*m**6*m_bar**5*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q) - 256*H**6*m**6*m_bar**5*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) + 256*H**6*m**6*m_bar**5*rho_sigma**6*u**2*v**6*exp(I*phi) - 384*H**6*m**6*m_bar**5*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 384*H**6*m**6*m_bar**5*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q) + 384*H**6*m**6*m_bar**5*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q_bar) - 384*H**6*m**6*m_bar**5*rho_sigma**4*u**4*v**4*exp(I*phi) + 256*H**6*m**6*m_bar**5*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 256*H**6*m**6*m_bar**5*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q) - 256*H**6*m**6*m_bar**5*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) + 256*H**6*m**6*m_bar**5*rho_sigma**2*u**6*v**2*exp(I*phi) - 64*H**6*m**6*m_bar**5*u**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 64*H**6*m**6*m_bar**5*u**8*exp(I*phi)*exp(2*I*L*q) + 64*H**6*m**6*m_bar**5*u**8*exp(I*phi)*exp(2*I*L*q_bar) - 64*H**6*m**6*m_bar**5*u**8*exp(I*phi) - 64*I*H**5*h_bar**2*k*m**5*m_bar**5*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 64*I*H**5*h_bar**2*k*m**5*m_bar**5*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q) + 64*I*H**5*h_bar**2*k*m**5*m_bar**5*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) - 64*I*H**5*h_bar**2*k*m**5*m_bar**5*rho_sigma**8*v**8*exp(I*phi) + 128*I*H**5*h_bar**2*k*m**5*m_bar**5*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 128*I*H**5*h_bar**2*k*m**5*m_bar**5*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q) - 128*I*H**5*h_bar**2*k*m**5*m_bar**5*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) + 128*I*H**5*h_bar**2*k*m**5*m_bar**5*rho_sigma**6*u**2*v**6*exp(I*phi) - 128*I*H**5*h_bar**2*k*m**5*m_bar**5*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 128*I*H**5*h_bar**2*k*m**5*m_bar**5*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q) + 128*I*H**5*h_bar**2*k*m**5*m_bar**5*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) - 128*I*H**5*h_bar**2*k*m**5*m_bar**5*rho_sigma**2*u**6*v**2*exp(I*phi) + 64*I*H**5*h_bar**2*k*m**5*m_bar**5*u**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 64*I*H**5*h_bar**2*k*m**5*m_bar**5*u**8*exp(I*phi)*exp(2*I*L*q) - 64*I*H**5*h_bar**2*k*m**5*m_bar**5*u**8*exp(I*phi)*exp(2*I*L*q_bar) + 64*I*H**5*h_bar**2*k*m**5*m_bar**5*u**8*exp(I*phi) - 128*I*H**5*h_bar**2*m**6*m_bar**4*q*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) + 128*I*H**5*h_bar**2*m**6*m_bar**4*q*rho_sigma**8*v**8*exp(I*phi) + 512*I*H**5*h_bar**2*m**6*m_bar**4*q*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) - 512*I*H**5*h_bar**2*m**6*m_bar**4*q*rho_sigma**6*u**2*v**6*exp(I*phi) - 768*I*H**5*h_bar**2*m**6*m_bar**4*q*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q_bar) + 768*I*H**5*h_bar**2*m**6*m_bar**4*q*rho_sigma**4*u**4*v**4*exp(I*phi) + 512*I*H**5*h_bar**2*m**6*m_bar**4*q*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) - 512*I*H**5*h_bar**2*m**6*m_bar**4*q*rho_sigma**2*u**6*v**2*exp(I*phi) - 128*I*H**5*h_bar**2*m**6*m_bar**4*q*u**8*exp(I*phi)*exp(2*I*L*q_bar) + 128*I*H**5*h_bar**2*m**6*m_bar**4*q*u**8*exp(I*phi) - 96*I*H**5*h_bar**2*m**6*m_bar**4*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 32*I*H**5*h_bar**2*m**6*m_bar**4*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q) + 96*I*H**5*h_bar**2*m**6*m_bar**4*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) + 32*I*H**5*h_bar**2*m**6*m_bar**4*q_bar*rho_sigma**8*v**8*exp(I*phi) + 384*I*H**5*h_bar**2*m**6*m_bar**4*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 128*I*H**5*h_bar**2*m**6*m_bar**4*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q) - 384*I*H**5*h_bar**2*m**6*m_bar**4*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) - 128*I*H**5*h_bar**2*m**6*m_bar**4*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi) - 576*I*H**5*h_bar**2*m**6*m_bar**4*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 192*I*H**5*h_bar**2*m**6*m_bar**4*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q) + 576*I*H**5*h_bar**2*m**6*m_bar**4*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q_bar) + 192*I*H**5*h_bar**2*m**6*m_bar**4*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi) + 384*I*H**5*h_bar**2*m**6*m_bar**4*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 128*I*H**5*h_bar**2*m**6*m_bar**4*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q) - 384*I*H**5*h_bar**2*m**6*m_bar**4*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) - 128*I*H**5*h_bar**2*m**6*m_bar**4*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi) - 96*I*H**5*h_bar**2*m**6*m_bar**4*q_bar*u**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 32*I*H**5*h_bar**2*m**6*m_bar**4*q_bar*u**8*exp(I*phi)*exp(2*I*L*q) + 96*I*H**5*h_bar**2*m**6*m_bar**4*q_bar*u**8*exp(I*phi)*exp(2*I*L*q_bar) + 32*I*H**5*h_bar**2*m**6*m_bar**4*q_bar*u**8*exp(I*phi) - 16*H**4*h_bar**4*k**2*m**4*m_bar**5*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 16*H**4*h_bar**4*k**2*m**4*m_bar**5*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q) + 16*H**4*h_bar**4*k**2*m**4*m_bar**5*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) - 16*H**4*h_bar**4*k**2*m**4*m_bar**5*rho_sigma**8*v**8*exp(I*phi) + 128*H**4*h_bar**4*k**2*m**4*m_bar**5*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 128*H**4*h_bar**4*k**2*m**4*m_bar**5*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q) - 128*H**4*h_bar**4*k**2*m**4*m_bar**5*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) + 128*H**4*h_bar**4*k**2*m**4*m_bar**5*rho_sigma**6*u**2*v**6*exp(I*phi) - 224*H**4*h_bar**4*k**2*m**4*m_bar**5*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 224*H**4*h_bar**4*k**2*m**4*m_bar**5*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q) + 224*H**4*h_bar**4*k**2*m**4*m_bar**5*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q_bar) - 224*H**4*h_bar**4*k**2*m**4*m_bar**5*rho_sigma**4*u**4*v**4*exp(I*phi) + 128*H**4*h_bar**4*k**2*m**4*m_bar**5*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 128*H**4*h_bar**4*k**2*m**4*m_bar**5*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q) - 128*H**4*h_bar**4*k**2*m**4*m_bar**5*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) + 128*H**4*h_bar**4*k**2*m**4*m_bar**5*rho_sigma**2*u**6*v**2*exp(I*phi) - 16*H**4*h_bar**4*k**2*m**4*m_bar**5*u**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 16*H**4*h_bar**4*k**2*m**4*m_bar**5*u**8*exp(I*phi)*exp(2*I*L*q) + 16*H**4*h_bar**4*k**2*m**4*m_bar**5*u**8*exp(I*phi)*exp(2*I*L*q_bar) - 16*H**4*h_bar**4*k**2*m**4*m_bar**5*u**8*exp(I*phi) + 64*H**4*h_bar**4*k*m**5*m_bar**4*q*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) - 64*H**4*h_bar**4*k*m**5*m_bar**4*q*rho_sigma**8*v**8*exp(I*phi) - 128*H**4*h_bar**4*k*m**5*m_bar**4*q*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) + 128*H**4*h_bar**4*k*m**5*m_bar**4*q*rho_sigma**6*u**2*v**6*exp(I*phi) + 128*H**4*h_bar**4*k*m**5*m_bar**4*q*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) - 128*H**4*h_bar**4*k*m**5*m_bar**4*q*rho_sigma**2*u**6*v**2*exp(I*phi) - 64*H**4*h_bar**4*k*m**5*m_bar**4*q*u**8*exp(I*phi)*exp(2*I*L*q_bar) + 64*H**4*h_bar**4*k*m**5*m_bar**4*q*u**8*exp(I*phi) + 144*H**4*h_bar**4*k*m**5*m_bar**4*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 48*H**4*h_bar**4*k*m**5*m_bar**4*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q) - 144*H**4*h_bar**4*k*m**5*m_bar**4*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) - 48*H**4*h_bar**4*k*m**5*m_bar**4*q_bar*rho_sigma**8*v**8*exp(I*phi) - 288*H**4*h_bar**4*k*m**5*m_bar**4*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 96*H**4*h_bar**4*k*m**5*m_bar**4*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q) + 288*H**4*h_bar**4*k*m**5*m_bar**4*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) + 96*H**4*h_bar**4*k*m**5*m_bar**4*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi) + 288*H**4*h_bar**4*k*m**5*m_bar**4*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 96*H**4*h_bar**4*k*m**5*m_bar**4*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q) - 288*H**4*h_bar**4*k*m**5*m_bar**4*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) - 96*H**4*h_bar**4*k*m**5*m_bar**4*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi) - 144*H**4*h_bar**4*k*m**5*m_bar**4*q_bar*u**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 48*H**4*h_bar**4*k*m**5*m_bar**4*q_bar*u**8*exp(I*phi)*exp(2*I*L*q) + 144*H**4*h_bar**4*k*m**5*m_bar**4*q_bar*u**8*exp(I*phi)*exp(2*I*L*q_bar) + 48*H**4*h_bar**4*k*m**5*m_bar**4*q_bar*u**8*exp(I*phi) - 32*H**4*h_bar**4*m**6*m_bar**3*q**2*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 32*H**4*h_bar**4*m**6*m_bar**3*q**2*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q) - 96*H**4*h_bar**4*m**6*m_bar**3*q**2*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) + 96*H**4*h_bar**4*m**6*m_bar**3*q**2*rho_sigma**8*v**8*exp(I*phi) + 128*H**4*h_bar**4*m**6*m_bar**3*q**2*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 128*H**4*h_bar**4*m**6*m_bar**3*q**2*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q) + 384*H**4*h_bar**4*m**6*m_bar**3*q**2*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) - 384*H**4*h_bar**4*m**6*m_bar**3*q**2*rho_sigma**6*u**2*v**6*exp(I*phi) - 192*H**4*h_bar**4*m**6*m_bar**3*q**2*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 192*H**4*h_bar**4*m**6*m_bar**3*q**2*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q) - 576*H**4*h_bar**4*m**6*m_bar**3*q**2*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q_bar) + 576*H**4*h_bar**4*m**6*m_bar**3*q**2*rho_sigma**4*u**4*v**4*exp(I*phi) + 128*H**4*h_bar**4*m**6*m_bar**3*q**2*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 128*H**4*h_bar**4*m**6*m_bar**3*q**2*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q) + 384*H**4*h_bar**4*m**6*m_bar**3*q**2*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) - 384*H**4*h_bar**4*m**6*m_bar**3*q**2*rho_sigma**2*u**6*v**2*exp(I*phi) - 32*H**4*h_bar**4*m**6*m_bar**3*q**2*u**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 32*H**4*h_bar**4*m**6*m_bar**3*q**2*u**8*exp(I*phi)*exp(2*I*L*q) - 96*H**4*h_bar**4*m**6*m_bar**3*q**2*u**8*exp(I*phi)*exp(2*I*L*q_bar) + 96*H**4*h_bar**4*m**6*m_bar**3*q**2*u**8*exp(I*phi) + 192*H**4*h_bar**4*m**6*m_bar**3*q*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) + 64*H**4*h_bar**4*m**6*m_bar**3*q*q_bar*rho_sigma**8*v**8*exp(I*phi) - 768*H**4*h_bar**4*m**6*m_bar**3*q*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) - 256*H**4*h_bar**4*m**6*m_bar**3*q*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi) + 1152*H**4*h_bar**4*m**6*m_bar**3*q*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q_bar) + 384*H**4*h_bar**4*m**6*m_bar**3*q*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi) - 768*H**4*h_bar**4*m**6*m_bar**3*q*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) - 256*H**4*h_bar**4*m**6*m_bar**3*q*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi) + 192*H**4*h_bar**4*m**6*m_bar**3*q*q_bar*u**8*exp(I*phi)*exp(2*I*L*q_bar) + 64*H**4*h_bar**4*m**6*m_bar**3*q*q_bar*u**8*exp(I*phi) - 32*I*H**3*h_bar**6*k**3*m**3*m_bar**5*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 32*I*H**3*h_bar**6*k**3*m**3*m_bar**5*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q) + 32*I*H**3*h_bar**6*k**3*m**3*m_bar**5*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) - 32*I*H**3*h_bar**6*k**3*m**3*m_bar**5*rho_sigma**8*v**8*exp(I*phi) + 64*I*H**3*h_bar**6*k**3*m**3*m_bar**5*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 64*I*H**3*h_bar**6*k**3*m**3*m_bar**5*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q) - 64*I*H**3*h_bar**6*k**3*m**3*m_bar**5*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) + 64*I*H**3*h_bar**6*k**3*m**3*m_bar**5*rho_sigma**6*u**2*v**6*exp(I*phi) - 64*I*H**3*h_bar**6*k**3*m**3*m_bar**5*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 64*I*H**3*h_bar**6*k**3*m**3*m_bar**5*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q) + 64*I*H**3*h_bar**6*k**3*m**3*m_bar**5*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) - 64*I*H**3*h_bar**6*k**3*m**3*m_bar**5*rho_sigma**2*u**6*v**2*exp(I*phi) + 32*I*H**3*h_bar**6*k**3*m**3*m_bar**5*u**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 32*I*H**3*h_bar**6*k**3*m**3*m_bar**5*u**8*exp(I*phi)*exp(2*I*L*q) - 32*I*H**3*h_bar**6*k**3*m**3*m_bar**5*u**8*exp(I*phi)*exp(2*I*L*q_bar) + 32*I*H**3*h_bar**6*k**3*m**3*m_bar**5*u**8*exp(I*phi) - 64*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) + 64*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q*rho_sigma**8*v**8*exp(I*phi) - 64*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 64*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q) + 192*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) - 192*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q*rho_sigma**6*u**2*v**6*exp(I*phi) + 128*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 128*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q) - 256*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q_bar) + 256*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q*rho_sigma**4*u**4*v**4*exp(I*phi) - 64*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 64*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q) + 192*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) - 192*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q*rho_sigma**2*u**6*v**2*exp(I*phi) - 64*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q*u**8*exp(I*phi)*exp(2*I*L*q_bar) + 64*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q*u**8*exp(I*phi) + 48*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 16*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q) - 48*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) - 16*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q_bar*rho_sigma**8*v**8*exp(I*phi) + 96*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 32*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q) - 96*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) - 32*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi) - 288*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 96*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q) + 288*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q_bar) + 96*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi) + 96*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 32*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q) - 96*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) - 32*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi) + 48*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q_bar*u**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 16*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q_bar*u**8*exp(I*phi)*exp(2*I*L*q) - 48*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q_bar*u**8*exp(I*phi)*exp(2*I*L*q_bar) - 16*I*H**3*h_bar**6*k**2*m**4*m_bar**4*q_bar*u**8*exp(I*phi) + 192*I*H**3*h_bar**6*k*m**5*m_bar**3*q*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) + 64*I*H**3*h_bar**6*k*m**5*m_bar**3*q*q_bar*rho_sigma**8*v**8*exp(I*phi) - 384*I*H**3*h_bar**6*k*m**5*m_bar**3*q*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) - 128*I*H**3*h_bar**6*k*m**5*m_bar**3*q*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi) + 384*I*H**3*h_bar**6*k*m**5*m_bar**3*q*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) + 128*I*H**3*h_bar**6*k*m**5*m_bar**3*q*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi) - 192*I*H**3*h_bar**6*k*m**5*m_bar**3*q*q_bar*u**8*exp(I*phi)*exp(2*I*L*q_bar) - 64*I*H**3*h_bar**6*k*m**5*m_bar**3*q*q_bar*u**8*exp(I*phi) + 32*I*H**3*h_bar**6*m**6*m_bar**2*q**3*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) - 32*I*H**3*h_bar**6*m**6*m_bar**2*q**3*rho_sigma**8*v**8*exp(I*phi) - 128*I*H**3*h_bar**6*m**6*m_bar**2*q**3*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) + 128*I*H**3*h_bar**6*m**6*m_bar**2*q**3*rho_sigma**6*u**2*v**6*exp(I*phi) + 192*I*H**3*h_bar**6*m**6*m_bar**2*q**3*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q_bar) - 192*I*H**3*h_bar**6*m**6*m_bar**2*q**3*rho_sigma**4*u**4*v**4*exp(I*phi) - 128*I*H**3*h_bar**6*m**6*m_bar**2*q**3*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) + 128*I*H**3*h_bar**6*m**6*m_bar**2*q**3*rho_sigma**2*u**6*v**2*exp(I*phi) + 32*I*H**3*h_bar**6*m**6*m_bar**2*q**3*u**8*exp(I*phi)*exp(2*I*L*q_bar) - 32*I*H**3*h_bar**6*m**6*m_bar**2*q**3*u**8*exp(I*phi) - 48*I*H**3*h_bar**6*m**6*m_bar**2*q**2*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 16*I*H**3*h_bar**6*m**6*m_bar**2*q**2*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q) - 144*I*H**3*h_bar**6*m**6*m_bar**2*q**2*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) - 48*I*H**3*h_bar**6*m**6*m_bar**2*q**2*q_bar*rho_sigma**8*v**8*exp(I*phi) + 192*I*H**3*h_bar**6*m**6*m_bar**2*q**2*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 64*I*H**3*h_bar**6*m**6*m_bar**2*q**2*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q) + 576*I*H**3*h_bar**6*m**6*m_bar**2*q**2*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) + 192*I*H**3*h_bar**6*m**6*m_bar**2*q**2*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi) - 288*I*H**3*h_bar**6*m**6*m_bar**2*q**2*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 96*I*H**3*h_bar**6*m**6*m_bar**2*q**2*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q) - 864*I*H**3*h_bar**6*m**6*m_bar**2*q**2*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q_bar) - 288*I*H**3*h_bar**6*m**6*m_bar**2*q**2*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi) + 192*I*H**3*h_bar**6*m**6*m_bar**2*q**2*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 64*I*H**3*h_bar**6*m**6*m_bar**2*q**2*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q) + 576*I*H**3*h_bar**6*m**6*m_bar**2*q**2*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) + 192*I*H**3*h_bar**6*m**6*m_bar**2*q**2*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi) - 48*I*H**3*h_bar**6*m**6*m_bar**2*q**2*q_bar*u**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 16*I*H**3*h_bar**6*m**6*m_bar**2*q**2*q_bar*u**8*exp(I*phi)*exp(2*I*L*q) - 144*I*H**3*h_bar**6*m**6*m_bar**2*q**2*q_bar*u**8*exp(I*phi)*exp(2*I*L*q_bar) - 48*I*H**3*h_bar**6*m**6*m_bar**2*q**2*q_bar*u**8*exp(I*phi) + 4*H**2*h_bar**8*k**4*m**2*m_bar**5*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 4*H**2*h_bar**8*k**4*m**2*m_bar**5*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q) - 4*H**2*h_bar**8*k**4*m**2*m_bar**5*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) + 4*H**2*h_bar**8*k**4*m**2*m_bar**5*rho_sigma**8*v**8*exp(I*phi) + 16*H**2*h_bar**8*k**4*m**2*m_bar**5*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 16*H**2*h_bar**8*k**4*m**2*m_bar**5*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q) - 16*H**2*h_bar**8*k**4*m**2*m_bar**5*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) + 16*H**2*h_bar**8*k**4*m**2*m_bar**5*rho_sigma**6*u**2*v**6*exp(I*phi) - 40*H**2*h_bar**8*k**4*m**2*m_bar**5*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 40*H**2*h_bar**8*k**4*m**2*m_bar**5*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q) + 40*H**2*h_bar**8*k**4*m**2*m_bar**5*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q_bar) - 40*H**2*h_bar**8*k**4*m**2*m_bar**5*rho_sigma**4*u**4*v**4*exp(I*phi) + 16*H**2*h_bar**8*k**4*m**2*m_bar**5*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 16*H**2*h_bar**8*k**4*m**2*m_bar**5*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q) - 16*H**2*h_bar**8*k**4*m**2*m_bar**5*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) + 16*H**2*h_bar**8*k**4*m**2*m_bar**5*rho_sigma**2*u**6*v**2*exp(I*phi) + 4*H**2*h_bar**8*k**4*m**2*m_bar**5*u**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 4*H**2*h_bar**8*k**4*m**2*m_bar**5*u**8*exp(I*phi)*exp(2*I*L*q) - 4*H**2*h_bar**8*k**4*m**2*m_bar**5*u**8*exp(I*phi)*exp(2*I*L*q_bar) + 4*H**2*h_bar**8*k**4*m**2*m_bar**5*u**8*exp(I*phi) + 32*H**2*h_bar**8*k**3*m**3*m_bar**4*q*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) - 32*H**2*h_bar**8*k**3*m**3*m_bar**4*q*rho_sigma**8*v**8*exp(I*phi) + 32*H**2*h_bar**8*k**3*m**3*m_bar**4*q*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 32*H**2*h_bar**8*k**3*m**3*m_bar**4*q*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q) - 32*H**2*h_bar**8*k**3*m**3*m_bar**4*q*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) + 32*H**2*h_bar**8*k**3*m**3*m_bar**4*q*rho_sigma**6*u**2*v**6*exp(I*phi) - 32*H**2*h_bar**8*k**3*m**3*m_bar**4*q*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 32*H**2*h_bar**8*k**3*m**3*m_bar**4*q*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q) + 32*H**2*h_bar**8*k**3*m**3*m_bar**4*q*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) - 32*H**2*h_bar**8*k**3*m**3*m_bar**4*q*rho_sigma**2*u**6*v**2*exp(I*phi) - 32*H**2*h_bar**8*k**3*m**3*m_bar**4*q*u**8*exp(I*phi)*exp(2*I*L*q_bar) + 32*H**2*h_bar**8*k**3*m**3*m_bar**4*q*u**8*exp(I*phi) + 24*H**2*h_bar**8*k**3*m**3*m_bar**4*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 8*H**2*h_bar**8*k**3*m**3*m_bar**4*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q) - 24*H**2*h_bar**8*k**3*m**3*m_bar**4*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) - 8*H**2*h_bar**8*k**3*m**3*m_bar**4*q_bar*rho_sigma**8*v**8*exp(I*phi) - 96*H**2*h_bar**8*k**3*m**3*m_bar**4*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 32*H**2*h_bar**8*k**3*m**3*m_bar**4*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q) + 96*H**2*h_bar**8*k**3*m**3*m_bar**4*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) + 32*H**2*h_bar**8*k**3*m**3*m_bar**4*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi) + 96*H**2*h_bar**8*k**3*m**3*m_bar**4*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 32*H**2*h_bar**8*k**3*m**3*m_bar**4*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q) - 96*H**2*h_bar**8*k**3*m**3*m_bar**4*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) - 32*H**2*h_bar**8*k**3*m**3*m_bar**4*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi) - 24*H**2*h_bar**8*k**3*m**3*m_bar**4*q_bar*u**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 8*H**2*h_bar**8*k**3*m**3*m_bar**4*q_bar*u**8*exp(I*phi)*exp(2*I*L*q) + 24*H**2*h_bar**8*k**3*m**3*m_bar**4*q_bar*u**8*exp(I*phi)*exp(2*I*L*q_bar) + 8*H**2*h_bar**8*k**3*m**3*m_bar**4*q_bar*u**8*exp(I*phi) - 16*H**2*h_bar**8*k**2*m**4*m_bar**3*q**2*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 16*H**2*h_bar**8*k**2*m**4*m_bar**3*q**2*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q) - 48*H**2*h_bar**8*k**2*m**4*m_bar**3*q**2*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) + 48*H**2*h_bar**8*k**2*m**4*m_bar**3*q**2*rho_sigma**8*v**8*exp(I*phi) + 32*H**2*h_bar**8*k**2*m**4*m_bar**3*q**2*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 32*H**2*h_bar**8*k**2*m**4*m_bar**3*q**2*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q) + 96*H**2*h_bar**8*k**2*m**4*m_bar**3*q**2*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) - 96*H**2*h_bar**8*k**2*m**4*m_bar**3*q**2*rho_sigma**6*u**2*v**6*exp(I*phi) - 32*H**2*h_bar**8*k**2*m**4*m_bar**3*q**2*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 32*H**2*h_bar**8*k**2*m**4*m_bar**3*q**2*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q) - 96*H**2*h_bar**8*k**2*m**4*m_bar**3*q**2*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q_bar) + 96*H**2*h_bar**8*k**2*m**4*m_bar**3*q**2*rho_sigma**4*u**4*v**4*exp(I*phi) + 32*H**2*h_bar**8*k**2*m**4*m_bar**3*q**2*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 32*H**2*h_bar**8*k**2*m**4*m_bar**3*q**2*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q) + 96*H**2*h_bar**8*k**2*m**4*m_bar**3*q**2*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) - 96*H**2*h_bar**8*k**2*m**4*m_bar**3*q**2*rho_sigma**2*u**6*v**2*exp(I*phi) - 16*H**2*h_bar**8*k**2*m**4*m_bar**3*q**2*u**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 16*H**2*h_bar**8*k**2*m**4*m_bar**3*q**2*u**8*exp(I*phi)*exp(2*I*L*q) - 48*H**2*h_bar**8*k**2*m**4*m_bar**3*q**2*u**8*exp(I*phi)*exp(2*I*L*q_bar) + 48*H**2*h_bar**8*k**2*m**4*m_bar**3*q**2*u**8*exp(I*phi) - 32*H**2*h_bar**8*k**2*m**4*m_bar**3*q*q_bar*rho_sigma**6*u**2*v**6*exp(2*I*phi)*exp(I*L*q)*exp(3*I*L*q_bar) - 32*H**2*h_bar**8*k**2*m**4*m_bar**3*q*q_bar*rho_sigma**6*u**2*v**6*exp(2*I*phi)*exp(I*L*q)*exp(I*L*q_bar) + 48*H**2*h_bar**8*k**2*m**4*m_bar**3*q*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 16*H**2*h_bar**8*k**2*m**4*m_bar**3*q*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q) - 144*H**2*h_bar**8*k**2*m**4*m_bar**3*q*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) - 48*H**2*h_bar**8*k**2*m**4*m_bar**3*q*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi) - 64*H**2*h_bar**8*k**2*m**4*m_bar**3*q*q_bar*rho_sigma**6*u**2*v**6*exp(I*L*q)*exp(I*L*q_bar) + 64*H**2*h_bar**8*k**2*m**4*m_bar**3*q*q_bar*rho_sigma**4*u**4*v**4*exp(2*I*phi)*exp(I*L*q)*exp(3*I*L*q_bar) + 64*H**2*h_bar**8*k**2*m**4*m_bar**3*q*q_bar*rho_sigma**4*u**4*v**4*exp(2*I*phi)*exp(I*L*q)*exp(I*L*q_bar) - 96*H**2*h_bar**8*k**2*m**4*m_bar**3*q*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 32*H**2*h_bar**8*k**2*m**4*m_bar**3*q*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q) + 288*H**2*h_bar**8*k**2*m**4*m_bar**3*q*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q_bar) + 96*H**2*h_bar**8*k**2*m**4*m_bar**3*q*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi) + 128*H**2*h_bar**8*k**2*m**4*m_bar**3*q*q_bar*rho_sigma**4*u**4*v**4*exp(I*L*q)*exp(I*L*q_bar) - 32*H**2*h_bar**8*k**2*m**4*m_bar**3*q*q_bar*rho_sigma**2*u**6*v**2*exp(2*I*phi)*exp(I*L*q)*exp(3*I*L*q_bar) - 32*H**2*h_bar**8*k**2*m**4*m_bar**3*q*q_bar*rho_sigma**2*u**6*v**2*exp(2*I*phi)*exp(I*L*q)*exp(I*L*q_bar) + 48*H**2*h_bar**8*k**2*m**4*m_bar**3*q*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 16*H**2*h_bar**8*k**2*m**4*m_bar**3*q*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q) - 144*H**2*h_bar**8*k**2*m**4*m_bar**3*q*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) - 48*H**2*h_bar**8*k**2*m**4*m_bar**3*q*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi) - 64*H**2*h_bar**8*k**2*m**4*m_bar**3*q*q_bar*rho_sigma**2*u**6*v**2*exp(I*L*q)*exp(I*L*q_bar) + 16*H**2*h_bar**8*k*m**5*m_bar**2*q**3*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) - 16*H**2*h_bar**8*k*m**5*m_bar**2*q**3*rho_sigma**8*v**8*exp(I*phi) - 32*H**2*h_bar**8*k*m**5*m_bar**2*q**3*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) + 32*H**2*h_bar**8*k*m**5*m_bar**2*q**3*rho_sigma**6*u**2*v**6*exp(I*phi) + 32*H**2*h_bar**8*k*m**5*m_bar**2*q**3*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) - 32*H**2*h_bar**8*k*m**5*m_bar**2*q**3*rho_sigma**2*u**6*v**2*exp(I*phi) - 16*H**2*h_bar**8*k*m**5*m_bar**2*q**3*u**8*exp(I*phi)*exp(2*I*L*q_bar) + 16*H**2*h_bar**8*k*m**5*m_bar**2*q**3*u**8*exp(I*phi) + 24*H**2*h_bar**8*k*m**5*m_bar**2*q**2*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 8*H**2*h_bar**8*k*m**5*m_bar**2*q**2*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q) + 72*H**2*h_bar**8*k*m**5*m_bar**2*q**2*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) + 24*H**2*h_bar**8*k*m**5*m_bar**2*q**2*q_bar*rho_sigma**8*v**8*exp(I*phi) - 48*H**2*h_bar**8*k*m**5*m_bar**2*q**2*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 16*H**2*h_bar**8*k*m**5*m_bar**2*q**2*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q) - 144*H**2*h_bar**8*k*m**5*m_bar**2*q**2*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) - 48*H**2*h_bar**8*k*m**5*m_bar**2*q**2*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi) + 48*H**2*h_bar**8*k*m**5*m_bar**2*q**2*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 16*H**2*h_bar**8*k*m**5*m_bar**2*q**2*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q) + 144*H**2*h_bar**8*k*m**5*m_bar**2*q**2*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) + 48*H**2*h_bar**8*k*m**5*m_bar**2*q**2*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi) - 24*H**2*h_bar**8*k*m**5*m_bar**2*q**2*q_bar*u**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 8*H**2*h_bar**8*k*m**5*m_bar**2*q**2*q_bar*u**8*exp(I*phi)*exp(2*I*L*q) - 72*H**2*h_bar**8*k*m**5*m_bar**2*q**2*q_bar*u**8*exp(I*phi)*exp(2*I*L*q_bar) - 24*H**2*h_bar**8*k*m**5*m_bar**2*q**2*q_bar*u**8*exp(I*phi) - 4*H**2*h_bar**8*m**6*m_bar*q**4*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 4*H**2*h_bar**8*m**6*m_bar*q**4*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q) + 4*H**2*h_bar**8*m**6*m_bar*q**4*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) - 4*H**2*h_bar**8*m**6*m_bar*q**4*rho_sigma**8*v**8*exp(I*phi) + 16*H**2*h_bar**8*m**6*m_bar*q**4*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 16*H**2*h_bar**8*m**6*m_bar*q**4*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q) - 16*H**2*h_bar**8*m**6*m_bar*q**4*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) + 16*H**2*h_bar**8*m**6*m_bar*q**4*rho_sigma**6*u**2*v**6*exp(I*phi) - 24*H**2*h_bar**8*m**6*m_bar*q**4*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 24*H**2*h_bar**8*m**6*m_bar*q**4*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q) + 24*H**2*h_bar**8*m**6*m_bar*q**4*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q_bar) - 24*H**2*h_bar**8*m**6*m_bar*q**4*rho_sigma**4*u**4*v**4*exp(I*phi) + 16*H**2*h_bar**8*m**6*m_bar*q**4*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 16*H**2*h_bar**8*m**6*m_bar*q**4*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q) - 16*H**2*h_bar**8*m**6*m_bar*q**4*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) + 16*H**2*h_bar**8*m**6*m_bar*q**4*rho_sigma**2*u**6*v**2*exp(I*phi) - 4*H**2*h_bar**8*m**6*m_bar*q**4*u**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 4*H**2*h_bar**8*m**6*m_bar*q**4*u**8*exp(I*phi)*exp(2*I*L*q) + 4*H**2*h_bar**8*m**6*m_bar*q**4*u**8*exp(I*phi)*exp(2*I*L*q_bar) - 4*H**2*h_bar**8*m**6*m_bar*q**4*u**8*exp(I*phi) - 48*H**2*h_bar**8*m**6*m_bar*q**3*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) - 16*H**2*h_bar**8*m**6*m_bar*q**3*q_bar*rho_sigma**8*v**8*exp(I*phi) + 192*H**2*h_bar**8*m**6*m_bar*q**3*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) + 64*H**2*h_bar**8*m**6*m_bar*q**3*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi) - 288*H**2*h_bar**8*m**6*m_bar*q**3*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q_bar) - 96*H**2*h_bar**8*m**6*m_bar*q**3*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi) + 192*H**2*h_bar**8*m**6*m_bar*q**3*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) + 64*H**2*h_bar**8*m**6*m_bar*q**3*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi) - 48*H**2*h_bar**8*m**6*m_bar*q**3*q_bar*u**8*exp(I*phi)*exp(2*I*L*q_bar) - 16*H**2*h_bar**8*m**6*m_bar*q**3*q_bar*u**8*exp(I*phi) - 4*I*H*h_bar**10*k**5*m*m_bar**5*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 4*I*H*h_bar**10*k**5*m*m_bar**5*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q) + 4*I*H*h_bar**10*k**5*m*m_bar**5*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) - 4*I*H*h_bar**10*k**5*m*m_bar**5*rho_sigma**8*v**8*exp(I*phi) + 8*I*H*h_bar**10*k**5*m*m_bar**5*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 8*I*H*h_bar**10*k**5*m*m_bar**5*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q) - 8*I*H*h_bar**10*k**5*m*m_bar**5*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) + 8*I*H*h_bar**10*k**5*m*m_bar**5*rho_sigma**6*u**2*v**6*exp(I*phi) - 8*I*H*h_bar**10*k**5*m*m_bar**5*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 8*I*H*h_bar**10*k**5*m*m_bar**5*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q) + 8*I*H*h_bar**10*k**5*m*m_bar**5*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) - 8*I*H*h_bar**10*k**5*m*m_bar**5*rho_sigma**2*u**6*v**2*exp(I*phi) + 4*I*H*h_bar**10*k**5*m*m_bar**5*u**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 4*I*H*h_bar**10*k**5*m*m_bar**5*u**8*exp(I*phi)*exp(2*I*L*q) - 4*I*H*h_bar**10*k**5*m*m_bar**5*u**8*exp(I*phi)*exp(2*I*L*q_bar) + 4*I*H*h_bar**10*k**5*m*m_bar**5*u**8*exp(I*phi) - 8*I*H*h_bar**10*k**4*m**2*m_bar**4*q*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) + 8*I*H*h_bar**10*k**4*m**2*m_bar**4*q*rho_sigma**8*v**8*exp(I*phi) - 16*I*H*h_bar**10*k**4*m**2*m_bar**4*q*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 16*I*H*h_bar**10*k**4*m**2*m_bar**4*q*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q) + 16*I*H*h_bar**10*k**4*m**2*m_bar**4*q*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) - 16*I*H*h_bar**10*k**4*m**2*m_bar**4*q*rho_sigma**6*u**2*v**6*exp(I*phi) + 32*I*H*h_bar**10*k**4*m**2*m_bar**4*q*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 32*I*H*h_bar**10*k**4*m**2*m_bar**4*q*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q) - 16*I*H*h_bar**10*k**4*m**2*m_bar**4*q*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q_bar) + 16*I*H*h_bar**10*k**4*m**2*m_bar**4*q*rho_sigma**4*u**4*v**4*exp(I*phi) - 16*I*H*h_bar**10*k**4*m**2*m_bar**4*q*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 16*I*H*h_bar**10*k**4*m**2*m_bar**4*q*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q) + 16*I*H*h_bar**10*k**4*m**2*m_bar**4*q*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) - 16*I*H*h_bar**10*k**4*m**2*m_bar**4*q*rho_sigma**2*u**6*v**2*exp(I*phi) - 8*I*H*h_bar**10*k**4*m**2*m_bar**4*q*u**8*exp(I*phi)*exp(2*I*L*q_bar) + 8*I*H*h_bar**10*k**4*m**2*m_bar**4*q*u**8*exp(I*phi) + 18*I*H*h_bar**10*k**4*m**2*m_bar**4*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 6*I*H*h_bar**10*k**4*m**2*m_bar**4*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q) - 18*I*H*h_bar**10*k**4*m**2*m_bar**4*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) - 6*I*H*h_bar**10*k**4*m**2*m_bar**4*q_bar*rho_sigma**8*v**8*exp(I*phi) - 36*I*H*h_bar**10*k**4*m**2*m_bar**4*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 12*I*H*h_bar**10*k**4*m**2*m_bar**4*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q) + 36*I*H*h_bar**10*k**4*m**2*m_bar**4*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q_bar) + 12*I*H*h_bar**10*k**4*m**2*m_bar**4*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi) + 18*I*H*h_bar**10*k**4*m**2*m_bar**4*q_bar*u**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 6*I*H*h_bar**10*k**4*m**2*m_bar**4*q_bar*u**8*exp(I*phi)*exp(2*I*L*q) - 18*I*H*h_bar**10*k**4*m**2*m_bar**4*q_bar*u**8*exp(I*phi)*exp(2*I*L*q_bar) - 6*I*H*h_bar**10*k**4*m**2*m_bar**4*q_bar*u**8*exp(I*phi) + 48*I*H*h_bar**10*k**3*m**3*m_bar**3*q*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) + 16*I*H*h_bar**10*k**3*m**3*m_bar**3*q*q_bar*rho_sigma**8*v**8*exp(I*phi) - 32*I*H*h_bar**10*k**3*m**3*m_bar**3*q*q_bar*rho_sigma**6*u**2*v**6*exp(2*I*phi)*exp(I*L*q)*exp(3*I*L*q_bar) - 32*I*H*h_bar**10*k**3*m**3*m_bar**3*q*q_bar*rho_sigma**6*u**2*v**6*exp(2*I*phi)*exp(I*L*q)*exp(I*L*q_bar) + 48*I*H*h_bar**10*k**3*m**3*m_bar**3*q*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 16*I*H*h_bar**10*k**3*m**3*m_bar**3*q*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q) - 48*I*H*h_bar**10*k**3*m**3*m_bar**3*q*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) - 16*I*H*h_bar**10*k**3*m**3*m_bar**3*q*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi) - 64*I*H*h_bar**10*k**3*m**3*m_bar**3*q*q_bar*rho_sigma**6*u**2*v**6*exp(I*L*q)*exp(I*L*q_bar) + 32*I*H*h_bar**10*k**3*m**3*m_bar**3*q*q_bar*rho_sigma**2*u**6*v**2*exp(2*I*phi)*exp(I*L*q)*exp(3*I*L*q_bar) + 32*I*H*h_bar**10*k**3*m**3*m_bar**3*q*q_bar*rho_sigma**2*u**6*v**2*exp(2*I*phi)*exp(I*L*q)*exp(I*L*q_bar) - 48*I*H*h_bar**10*k**3*m**3*m_bar**3*q*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 16*I*H*h_bar**10*k**3*m**3*m_bar**3*q*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q) + 48*I*H*h_bar**10*k**3*m**3*m_bar**3*q*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) + 16*I*H*h_bar**10*k**3*m**3*m_bar**3*q*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi) + 64*I*H*h_bar**10*k**3*m**3*m_bar**3*q*q_bar*rho_sigma**2*u**6*v**2*exp(I*L*q)*exp(I*L*q_bar) - 48*I*H*h_bar**10*k**3*m**3*m_bar**3*q*q_bar*u**8*exp(I*phi)*exp(2*I*L*q_bar) - 16*I*H*h_bar**10*k**3*m**3*m_bar**3*q*q_bar*u**8*exp(I*phi) + 8*I*H*h_bar**10*k**2*m**4*m_bar**2*q**3*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) - 8*I*H*h_bar**10*k**2*m**4*m_bar**2*q**3*rho_sigma**8*v**8*exp(I*phi) - 16*I*H*h_bar**10*k**2*m**4*m_bar**2*q**3*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 16*I*H*h_bar**10*k**2*m**4*m_bar**2*q**3*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q) - 16*I*H*h_bar**10*k**2*m**4*m_bar**2*q**3*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) + 16*I*H*h_bar**10*k**2*m**4*m_bar**2*q**3*rho_sigma**6*u**2*v**6*exp(I*phi) + 32*I*H*h_bar**10*k**2*m**4*m_bar**2*q**3*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 32*I*H*h_bar**10*k**2*m**4*m_bar**2*q**3*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q) + 16*I*H*h_bar**10*k**2*m**4*m_bar**2*q**3*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q_bar) - 16*I*H*h_bar**10*k**2*m**4*m_bar**2*q**3*rho_sigma**4*u**4*v**4*exp(I*phi) - 16*I*H*h_bar**10*k**2*m**4*m_bar**2*q**3*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 16*I*H*h_bar**10*k**2*m**4*m_bar**2*q**3*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q) - 16*I*H*h_bar**10*k**2*m**4*m_bar**2*q**3*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) + 16*I*H*h_bar**10*k**2*m**4*m_bar**2*q**3*rho_sigma**2*u**6*v**2*exp(I*phi) + 8*I*H*h_bar**10*k**2*m**4*m_bar**2*q**3*u**8*exp(I*phi)*exp(2*I*L*q_bar) - 8*I*H*h_bar**10*k**2*m**4*m_bar**2*q**3*u**8*exp(I*phi) - 12*I*H*h_bar**10*k**2*m**4*m_bar**2*q**2*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 4*I*H*h_bar**10*k**2*m**4*m_bar**2*q**2*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q) - 36*I*H*h_bar**10*k**2*m**4*m_bar**2*q**2*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) - 12*I*H*h_bar**10*k**2*m**4*m_bar**2*q**2*q_bar*rho_sigma**8*v**8*exp(I*phi) + 32*I*H*h_bar**10*k**2*m**4*m_bar**2*q**2*q_bar*rho_sigma**6*u**2*v**6*exp(2*I*phi)*exp(I*L*q)*exp(3*I*L*q_bar) + 32*I*H*h_bar**10*k**2*m**4*m_bar**2*q**2*q_bar*rho_sigma**6*u**2*v**6*exp(2*I*phi)*exp(I*L*q)*exp(I*L*q_bar) + 24*I*H*h_bar**10*k**2*m**4*m_bar**2*q**2*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 8*I*H*h_bar**10*k**2*m**4*m_bar**2*q**2*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q) + 72*I*H*h_bar**10*k**2*m**4*m_bar**2*q**2*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) + 24*I*H*h_bar**10*k**2*m**4*m_bar**2*q**2*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi) + 64*I*H*h_bar**10*k**2*m**4*m_bar**2*q**2*q_bar*rho_sigma**6*u**2*v**6*exp(I*L*q)*exp(I*L*q_bar) - 64*I*H*h_bar**10*k**2*m**4*m_bar**2*q**2*q_bar*rho_sigma**4*u**4*v**4*exp(2*I*phi)*exp(I*L*q)*exp(3*I*L*q_bar) - 64*I*H*h_bar**10*k**2*m**4*m_bar**2*q**2*q_bar*rho_sigma**4*u**4*v**4*exp(2*I*phi)*exp(I*L*q)*exp(I*L*q_bar) - 24*I*H*h_bar**10*k**2*m**4*m_bar**2*q**2*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 8*I*H*h_bar**10*k**2*m**4*m_bar**2*q**2*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q) - 72*I*H*h_bar**10*k**2*m**4*m_bar**2*q**2*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q_bar) - 24*I*H*h_bar**10*k**2*m**4*m_bar**2*q**2*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi) - 128*I*H*h_bar**10*k**2*m**4*m_bar**2*q**2*q_bar*rho_sigma**4*u**4*v**4*exp(I*L*q)*exp(I*L*q_bar) + 32*I*H*h_bar**10*k**2*m**4*m_bar**2*q**2*q_bar*rho_sigma**2*u**6*v**2*exp(2*I*phi)*exp(I*L*q)*exp(3*I*L*q_bar) + 32*I*H*h_bar**10*k**2*m**4*m_bar**2*q**2*q_bar*rho_sigma**2*u**6*v**2*exp(2*I*phi)*exp(I*L*q)*exp(I*L*q_bar) + 24*I*H*h_bar**10*k**2*m**4*m_bar**2*q**2*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 8*I*H*h_bar**10*k**2*m**4*m_bar**2*q**2*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q) + 72*I*H*h_bar**10*k**2*m**4*m_bar**2*q**2*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) + 24*I*H*h_bar**10*k**2*m**4*m_bar**2*q**2*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi) + 64*I*H*h_bar**10*k**2*m**4*m_bar**2*q**2*q_bar*rho_sigma**2*u**6*v**2*exp(I*L*q)*exp(I*L*q_bar) - 12*I*H*h_bar**10*k**2*m**4*m_bar**2*q**2*q_bar*u**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 4*I*H*h_bar**10*k**2*m**4*m_bar**2*q**2*q_bar*u**8*exp(I*phi)*exp(2*I*L*q) - 36*I*H*h_bar**10*k**2*m**4*m_bar**2*q**2*q_bar*u**8*exp(I*phi)*exp(2*I*L*q_bar) - 12*I*H*h_bar**10*k**2*m**4*m_bar**2*q**2*q_bar*u**8*exp(I*phi) + 4*I*H*h_bar**10*k*m**5*m_bar*q**4*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 4*I*H*h_bar**10*k*m**5*m_bar*q**4*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q) - 4*I*H*h_bar**10*k*m**5*m_bar*q**4*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) + 4*I*H*h_bar**10*k*m**5*m_bar*q**4*rho_sigma**8*v**8*exp(I*phi) - 8*I*H*h_bar**10*k*m**5*m_bar*q**4*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 8*I*H*h_bar**10*k*m**5*m_bar*q**4*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q) + 8*I*H*h_bar**10*k*m**5*m_bar*q**4*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) - 8*I*H*h_bar**10*k*m**5*m_bar*q**4*rho_sigma**6*u**2*v**6*exp(I*phi) + 8*I*H*h_bar**10*k*m**5*m_bar*q**4*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 8*I*H*h_bar**10*k*m**5*m_bar*q**4*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q) - 8*I*H*h_bar**10*k*m**5*m_bar*q**4*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) + 8*I*H*h_bar**10*k*m**5*m_bar*q**4*rho_sigma**2*u**6*v**2*exp(I*phi) - 4*I*H*h_bar**10*k*m**5*m_bar*q**4*u**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 4*I*H*h_bar**10*k*m**5*m_bar*q**4*u**8*exp(I*phi)*exp(2*I*L*q) + 4*I*H*h_bar**10*k*m**5*m_bar*q**4*u**8*exp(I*phi)*exp(2*I*L*q_bar) - 4*I*H*h_bar**10*k*m**5*m_bar*q**4*u**8*exp(I*phi) - 6*I*H*h_bar**10*m**6*q**4*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 2*I*H*h_bar**10*m**6*q**4*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q) + 6*I*H*h_bar**10*m**6*q**4*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) + 2*I*H*h_bar**10*m**6*q**4*q_bar*rho_sigma**8*v**8*exp(I*phi) + 24*I*H*h_bar**10*m**6*q**4*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 8*I*H*h_bar**10*m**6*q**4*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q) - 24*I*H*h_bar**10*m**6*q**4*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) - 8*I*H*h_bar**10*m**6*q**4*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi) - 36*I*H*h_bar**10*m**6*q**4*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 12*I*H*h_bar**10*m**6*q**4*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q) + 36*I*H*h_bar**10*m**6*q**4*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q_bar) + 12*I*H*h_bar**10*m**6*q**4*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi) + 24*I*H*h_bar**10*m**6*q**4*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 8*I*H*h_bar**10*m**6*q**4*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q) - 24*I*H*h_bar**10*m**6*q**4*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) - 8*I*H*h_bar**10*m**6*q**4*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi) - 6*I*H*h_bar**10*m**6*q**4*q_bar*u**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 2*I*H*h_bar**10*m**6*q**4*q_bar*u**8*exp(I*phi)*exp(2*I*L*q) + 6*I*H*h_bar**10*m**6*q**4*q_bar*u**8*exp(I*phi)*exp(2*I*L*q_bar) + 2*I*H*h_bar**10*m**6*q**4*q_bar*u**8*exp(I*phi) + h_bar**12*k**6*m_bar**5*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - h_bar**12*k**6*m_bar**5*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q) - h_bar**12*k**6*m_bar**5*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) + h_bar**12*k**6*m_bar**5*rho_sigma**8*v**8*exp(I*phi) - 2*h_bar**12*k**6*m_bar**5*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 2*h_bar**12*k**6*m_bar**5*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q) + 2*h_bar**12*k**6*m_bar**5*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q_bar) - 2*h_bar**12*k**6*m_bar**5*rho_sigma**4*u**4*v**4*exp(I*phi) + h_bar**12*k**6*m_bar**5*u**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - h_bar**12*k**6*m_bar**5*u**8*exp(I*phi)*exp(2*I*L*q) - h_bar**12*k**6*m_bar**5*u**8*exp(I*phi)*exp(2*I*L*q_bar) + h_bar**12*k**6*m_bar**5*u**8*exp(I*phi) + 4*h_bar**12*k**5*m*m_bar**4*q*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) - 4*h_bar**12*k**5*m*m_bar**4*q*rho_sigma**8*v**8*exp(I*phi) + 8*h_bar**12*k**5*m*m_bar**4*q*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 8*h_bar**12*k**5*m*m_bar**4*q*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q) - 8*h_bar**12*k**5*m*m_bar**4*q*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 8*h_bar**12*k**5*m*m_bar**4*q*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q) - 4*h_bar**12*k**5*m*m_bar**4*q*u**8*exp(I*phi)*exp(2*I*L*q_bar) + 4*h_bar**12*k**5*m*m_bar**4*q*u**8*exp(I*phi) - 3*h_bar**12*k**5*m*m_bar**4*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - h_bar**12*k**5*m*m_bar**4*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q) + 3*h_bar**12*k**5*m*m_bar**4*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) + h_bar**12*k**5*m*m_bar**4*q_bar*rho_sigma**8*v**8*exp(I*phi) - 6*h_bar**12*k**5*m*m_bar**4*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 2*h_bar**12*k**5*m*m_bar**4*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q) + 6*h_bar**12*k**5*m*m_bar**4*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) + 2*h_bar**12*k**5*m*m_bar**4*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi) + 6*h_bar**12*k**5*m*m_bar**4*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 2*h_bar**12*k**5*m*m_bar**4*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q) - 6*h_bar**12*k**5*m*m_bar**4*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) - 2*h_bar**12*k**5*m*m_bar**4*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi) + 3*h_bar**12*k**5*m*m_bar**4*q_bar*u**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + h_bar**12*k**5*m*m_bar**4*q_bar*u**8*exp(I*phi)*exp(2*I*L*q) - 3*h_bar**12*k**5*m*m_bar**4*q_bar*u**8*exp(I*phi)*exp(2*I*L*q_bar) - h_bar**12*k**5*m*m_bar**4*q_bar*u**8*exp(I*phi) - 2*h_bar**12*k**4*m**2*m_bar**3*q**2*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 2*h_bar**12*k**4*m**2*m_bar**3*q**2*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q) - 6*h_bar**12*k**4*m**2*m_bar**3*q**2*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) + 6*h_bar**12*k**4*m**2*m_bar**3*q**2*rho_sigma**8*v**8*exp(I*phi) + 20*h_bar**12*k**4*m**2*m_bar**3*q**2*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 20*h_bar**12*k**4*m**2*m_bar**3*q**2*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q) - 4*h_bar**12*k**4*m**2*m_bar**3*q**2*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q_bar) + 4*h_bar**12*k**4*m**2*m_bar**3*q**2*rho_sigma**4*u**4*v**4*exp(I*phi) - 2*h_bar**12*k**4*m**2*m_bar**3*q**2*u**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 2*h_bar**12*k**4*m**2*m_bar**3*q**2*u**8*exp(I*phi)*exp(2*I*L*q) - 6*h_bar**12*k**4*m**2*m_bar**3*q**2*u**8*exp(I*phi)*exp(2*I*L*q_bar) + 6*h_bar**12*k**4*m**2*m_bar**3*q**2*u**8*exp(I*phi) - 12*h_bar**12*k**4*m**2*m_bar**3*q*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) - 4*h_bar**12*k**4*m**2*m_bar**3*q*q_bar*rho_sigma**8*v**8*exp(I*phi) + 8*h_bar**12*k**4*m**2*m_bar**3*q*q_bar*rho_sigma**6*u**2*v**6*exp(2*I*phi)*exp(I*L*q)*exp(3*I*L*q_bar) + 8*h_bar**12*k**4*m**2*m_bar**3*q*q_bar*rho_sigma**6*u**2*v**6*exp(2*I*phi)*exp(I*L*q)*exp(I*L*q_bar) - 12*h_bar**12*k**4*m**2*m_bar**3*q*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 4*h_bar**12*k**4*m**2*m_bar**3*q*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q) - 12*h_bar**12*k**4*m**2*m_bar**3*q*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) - 4*h_bar**12*k**4*m**2*m_bar**3*q*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi) + 16*h_bar**12*k**4*m**2*m_bar**3*q*q_bar*rho_sigma**6*u**2*v**6*exp(I*L*q)*exp(I*L*q_bar) + 16*h_bar**12*k**4*m**2*m_bar**3*q*q_bar*rho_sigma**4*u**4*v**4*exp(2*I*phi)*exp(I*L*q)*exp(3*I*L*q_bar) + 16*h_bar**12*k**4*m**2*m_bar**3*q*q_bar*rho_sigma**4*u**4*v**4*exp(2*I*phi)*exp(I*L*q)*exp(I*L*q_bar) - 24*h_bar**12*k**4*m**2*m_bar**3*q*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 8*h_bar**12*k**4*m**2*m_bar**3*q*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q) + 32*h_bar**12*k**4*m**2*m_bar**3*q*q_bar*rho_sigma**4*u**4*v**4*exp(I*L*q)*exp(I*L*q_bar) + 8*h_bar**12*k**4*m**2*m_bar**3*q*q_bar*rho_sigma**2*u**6*v**2*exp(2*I*phi)*exp(I*L*q)*exp(3*I*L*q_bar) + 8*h_bar**12*k**4*m**2*m_bar**3*q*q_bar*rho_sigma**2*u**6*v**2*exp(2*I*phi)*exp(I*L*q)*exp(I*L*q_bar) - 12*h_bar**12*k**4*m**2*m_bar**3*q*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 4*h_bar**12*k**4*m**2*m_bar**3*q*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q) - 12*h_bar**12*k**4*m**2*m_bar**3*q*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) - 4*h_bar**12*k**4*m**2*m_bar**3*q*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi) + 16*h_bar**12*k**4*m**2*m_bar**3*q*q_bar*rho_sigma**2*u**6*v**2*exp(I*L*q)*exp(I*L*q_bar) - 12*h_bar**12*k**4*m**2*m_bar**3*q*q_bar*u**8*exp(I*phi)*exp(2*I*L*q_bar) - 4*h_bar**12*k**4*m**2*m_bar**3*q*q_bar*u**8*exp(I*phi) + 4*h_bar**12*k**3*m**3*m_bar**2*q**3*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) - 4*h_bar**12*k**3*m**3*m_bar**2*q**3*rho_sigma**8*v**8*exp(I*phi) - 8*h_bar**12*k**3*m**3*m_bar**2*q**3*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 8*h_bar**12*k**3*m**3*m_bar**2*q**3*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q) + 8*h_bar**12*k**3*m**3*m_bar**2*q**3*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 8*h_bar**12*k**3*m**3*m_bar**2*q**3*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q) - 4*h_bar**12*k**3*m**3*m_bar**2*q**3*u**8*exp(I*phi)*exp(2*I*L*q_bar) + 4*h_bar**12*k**3*m**3*m_bar**2*q**3*u**8*exp(I*phi) + 6*h_bar**12*k**3*m**3*m_bar**2*q**2*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 2*h_bar**12*k**3*m**3*m_bar**2*q**2*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q) + 18*h_bar**12*k**3*m**3*m_bar**2*q**2*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) + 6*h_bar**12*k**3*m**3*m_bar**2*q**2*q_bar*rho_sigma**8*v**8*exp(I*phi) - 16*h_bar**12*k**3*m**3*m_bar**2*q**2*q_bar*rho_sigma**6*u**2*v**6*exp(2*I*phi)*exp(I*L*q)*exp(3*I*L*q_bar) - 16*h_bar**12*k**3*m**3*m_bar**2*q**2*q_bar*rho_sigma**6*u**2*v**6*exp(2*I*phi)*exp(I*L*q)*exp(I*L*q_bar) - 32*h_bar**12*k**3*m**3*m_bar**2*q**2*q_bar*rho_sigma**6*u**2*v**6*exp(I*L*q)*exp(I*L*q_bar) + 16*h_bar**12*k**3*m**3*m_bar**2*q**2*q_bar*rho_sigma**2*u**6*v**2*exp(2*I*phi)*exp(I*L*q)*exp(3*I*L*q_bar) + 16*h_bar**12*k**3*m**3*m_bar**2*q**2*q_bar*rho_sigma**2*u**6*v**2*exp(2*I*phi)*exp(I*L*q)*exp(I*L*q_bar) + 32*h_bar**12*k**3*m**3*m_bar**2*q**2*q_bar*rho_sigma**2*u**6*v**2*exp(I*L*q)*exp(I*L*q_bar) - 6*h_bar**12*k**3*m**3*m_bar**2*q**2*q_bar*u**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 2*h_bar**12*k**3*m**3*m_bar**2*q**2*q_bar*u**8*exp(I*phi)*exp(2*I*L*q) - 18*h_bar**12*k**3*m**3*m_bar**2*q**2*q_bar*u**8*exp(I*phi)*exp(2*I*L*q_bar) - 6*h_bar**12*k**3*m**3*m_bar**2*q**2*q_bar*u**8*exp(I*phi) + h_bar**12*k**2*m**4*m_bar*q**4*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - h_bar**12*k**2*m**4*m_bar*q**4*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q) - h_bar**12*k**2*m**4*m_bar*q**4*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) + h_bar**12*k**2*m**4*m_bar*q**4*rho_sigma**8*v**8*exp(I*phi) - 2*h_bar**12*k**2*m**4*m_bar*q**4*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 2*h_bar**12*k**2*m**4*m_bar*q**4*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q) + 2*h_bar**12*k**2*m**4*m_bar*q**4*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q_bar) - 2*h_bar**12*k**2*m**4*m_bar*q**4*rho_sigma**4*u**4*v**4*exp(I*phi) + h_bar**12*k**2*m**4*m_bar*q**4*u**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - h_bar**12*k**2*m**4*m_bar*q**4*u**8*exp(I*phi)*exp(2*I*L*q) - h_bar**12*k**2*m**4*m_bar*q**4*u**8*exp(I*phi)*exp(2*I*L*q_bar) + h_bar**12*k**2*m**4*m_bar*q**4*u**8*exp(I*phi) - 12*h_bar**12*k**2*m**4*m_bar*q**3*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) - 4*h_bar**12*k**2*m**4*m_bar*q**3*q_bar*rho_sigma**8*v**8*exp(I*phi) + 8*h_bar**12*k**2*m**4*m_bar*q**3*q_bar*rho_sigma**6*u**2*v**6*exp(2*I*phi)*exp(I*L*q)*exp(3*I*L*q_bar) + 8*h_bar**12*k**2*m**4*m_bar*q**3*q_bar*rho_sigma**6*u**2*v**6*exp(2*I*phi)*exp(I*L*q)*exp(I*L*q_bar) + 12*h_bar**12*k**2*m**4*m_bar*q**3*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 4*h_bar**12*k**2*m**4*m_bar*q**3*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q) + 12*h_bar**12*k**2*m**4*m_bar*q**3*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) + 4*h_bar**12*k**2*m**4*m_bar*q**3*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi) + 16*h_bar**12*k**2*m**4*m_bar*q**3*q_bar*rho_sigma**6*u**2*v**6*exp(I*L*q)*exp(I*L*q_bar) - 16*h_bar**12*k**2*m**4*m_bar*q**3*q_bar*rho_sigma**4*u**4*v**4*exp(2*I*phi)*exp(I*L*q)*exp(3*I*L*q_bar) - 16*h_bar**12*k**2*m**4*m_bar*q**3*q_bar*rho_sigma**4*u**4*v**4*exp(2*I*phi)*exp(I*L*q)*exp(I*L*q_bar) - 24*h_bar**12*k**2*m**4*m_bar*q**3*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 8*h_bar**12*k**2*m**4*m_bar*q**3*q_bar*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q) - 32*h_bar**12*k**2*m**4*m_bar*q**3*q_bar*rho_sigma**4*u**4*v**4*exp(I*L*q)*exp(I*L*q_bar) + 8*h_bar**12*k**2*m**4*m_bar*q**3*q_bar*rho_sigma**2*u**6*v**2*exp(2*I*phi)*exp(I*L*q)*exp(3*I*L*q_bar) + 8*h_bar**12*k**2*m**4*m_bar*q**3*q_bar*rho_sigma**2*u**6*v**2*exp(2*I*phi)*exp(I*L*q)*exp(I*L*q_bar) + 12*h_bar**12*k**2*m**4*m_bar*q**3*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 4*h_bar**12*k**2*m**4*m_bar*q**3*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q) + 12*h_bar**12*k**2*m**4*m_bar*q**3*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) + 4*h_bar**12*k**2*m**4*m_bar*q**3*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi) + 16*h_bar**12*k**2*m**4*m_bar*q**3*q_bar*rho_sigma**2*u**6*v**2*exp(I*L*q)*exp(I*L*q_bar) - 12*h_bar**12*k**2*m**4*m_bar*q**3*q_bar*u**8*exp(I*phi)*exp(2*I*L*q_bar) - 4*h_bar**12*k**2*m**4*m_bar*q**3*q_bar*u**8*exp(I*phi) - 3*h_bar**12*k*m**5*q**4*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - h_bar**12*k*m**5*q**4*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q) + 3*h_bar**12*k*m**5*q**4*q_bar*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) + h_bar**12*k*m**5*q**4*q_bar*rho_sigma**8*v**8*exp(I*phi) + 6*h_bar**12*k*m**5*q**4*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 2*h_bar**12*k*m**5*q**4*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q) - 6*h_bar**12*k*m**5*q**4*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) - 2*h_bar**12*k*m**5*q**4*q_bar*rho_sigma**6*u**2*v**6*exp(I*phi) - 6*h_bar**12*k*m**5*q**4*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 2*h_bar**12*k*m**5*q**4*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q) + 6*h_bar**12*k*m**5*q**4*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q_bar) + 2*h_bar**12*k*m**5*q**4*q_bar*rho_sigma**2*u**6*v**2*exp(I*phi) + 3*h_bar**12*k*m**5*q**4*q_bar*u**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + h_bar**12*k*m**5*q**4*q_bar*u**8*exp(I*phi)*exp(2*I*L*q) - 3*h_bar**12*k*m**5*q**4*q_bar*u**8*exp(I*phi)*exp(2*I*L*q_bar) - h_bar**12*k*m**5*q**4*q_bar*u**8*exp(I*phi))/(-4*H**2*h_bar**8*m**6*m_bar**5*rho_sigma**4*v**4*exp(I*phi)*exp(2*I*L*q_bar) + 8*H**2*h_bar**8*m**6*m_bar**5*rho_sigma**2*u**2*v**2*exp(I*phi)*exp(2*I*L*q_bar) - 4*H**2*h_bar**8*m**6*m_bar**5*u**4*exp(I*phi)*exp(2*I*L*q_bar) - 4*I*H*h_bar**10*k*m**5*m_bar**5*rho_sigma**4*v**4*exp(I*phi)*exp(2*I*L*q_bar) + 4*I*H*h_bar**10*k*m**5*m_bar**5*u**4*exp(I*phi)*exp(2*I*L*q_bar) + 4*I*H*h_bar**10*m**6*m_bar**4*q*rho_sigma**4*v**4*exp(I*phi)*exp(2*I*L*q_bar) - 8*I*H*h_bar**10*m**6*m_bar**4*q*rho_sigma**2*u**2*v**2*exp(I*phi)*exp(2*I*L*q_bar) + 4*I*H*h_bar**10*m**6*m_bar**4*q*u**4*exp(I*phi)*exp(2*I*L*q_bar) + h_bar**12*k**2*m**4*m_bar**5*rho_sigma**4*v**4*exp(I*phi)*exp(2*I*L*q_bar) + 2*h_bar**12*k**2*m**4*m_bar**5*rho_sigma**2*u**2*v**2*exp(I*phi)*exp(2*I*L*q_bar) + h_bar**12*k**2*m**4*m_bar**5*u**4*exp(I*phi)*exp(2*I*L*q_bar) - 2*h_bar**12*k*m**5*m_bar**4*q*rho_sigma**4*v**4*exp(I*phi)*exp(2*I*L*q_bar) + 2*h_bar**12*k*m**5*m_bar**4*q*u**4*exp(I*phi)*exp(2*I*L*q_bar) + h_bar**12*m**6*m_bar**3*q**2*rho_sigma**4*v**4*exp(I*phi)*exp(2*I*L*q_bar) - 2*h_bar**12*m**6*m_bar**3*q**2*rho_sigma**2*u**2*v**2*exp(I*phi)*exp(2*I*L*q_bar) + h_bar**12*m**6*m_bar**3*q**2*u**4*exp(I*phi)*exp(2*I*L*q_bar))

# %%
tmp
# Out:
# (-64*H**6*m**6*m_bar**5*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 64*H**6*m**6*m_bar**5*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q) + 64*H**6*m**6*m_bar**5*rho_sigma**8*v**8*exp(I*phi)*exp(2*I*L*q_bar) - 64*H**6*m**6*m_bar**5*rho_sigma**8*v**8*exp(I*phi) + 256*H**6*m**6*m_bar**5*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 256*H**6*m**6*m_bar**5*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q) - 256*H**6*m**6*m_bar**5*rho_sigma**6*u**2*v**6*exp(I*phi)*exp(2*I*L*q_bar) + 256*H**6*m**6*m_bar**5*rho_sigma**6*u**2*v**6*exp(I*phi) - 384*H**6*m**6*m_bar**5*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) + 384*H**6*m**6*m_bar**5*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q) + 384*H**6*m**6*m_bar**5*rho_sigma**4*u**4*v**4*exp(I*phi)*exp(2*I*L*q_bar) - 384*H**6*m**6*m_bar**5*rho_sigma**4*u**4*v**4*exp(I*phi) + 256*H**6*m**6*m_bar**5*rho_sigma**2*u**6*v**2*exp(I*phi)*exp(2*I*L*q)*exp(2*I*L*q_bar) - 256*H**6*m**6*m_bar**5*rho_sigma**2*u**6*v*
# ...

# %%
nonlinsolve(eqs, a, b, c, d, alpha, beta, gamma, delta)
#linsolve((A,b), [a, b, c, d, alpha, beta, gamma, delta])
# Out:
# --------------------------------------------------------------------------
# KeyboardInterrupt                        Traceback (most recent call last)
# <ipython-input-33-29ddecb3f9c8> in <module>
# ----> 1 nonlinsolve(eqs, a, b, c, d, alpha, beta, gamma, delta)
#       2 #linsolve((A,b), [a, b, c, d, alpha, beta, gamma, delta])
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/solvers/solveset.py in nonlinsolve(system, *symbols)
#    3505     if len(symbols) == len(polys):
#    3506         # If all the equations in the system are poly
# -> 3507         if is_zero_dimensional(polys, symbols):
#    3508             # finite number of soln (Zero dimensional system)
#    3509             try:
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/polys/polytools.py in is_zero_dimensional(F, *gens, **args)
#    6858
#    6859     """
# -> 6860     return GroebnerBasis(F, *gens, **args).is_zero_dimensional
#    6861
#    6862
#
# ...

# %%
solve(A*x,x)
# Out:
# {x: 0}

# %%
B = np.random.random((8,8))

# %%
tmp = B*x

# %%
tmp
# Out:
# Matrix([
# [    0.197789064978923*a + 0.5629042319963*alpha + 0.663014209482942*b + 0.913128012726481*beta + 0.848562150700636*c + 0.117648467285693*d + 0.677846191684342*delta + 0.82743618090451*gamma],
# [  0.31670075267068*a + 0.463229610498106*alpha + 0.409071324323127*b + 0.288020645416362*beta + 0.521298213014918*c + 0.704990650414872*d + 0.725790804863365*delta + 0.781954560362491*gamma],
# [0.553037422689722*a + 0.982733391549303*alpha + 0.675163216275299*b + 0.0634272181633514*beta + 0.367462039601268*c + 0.406015582664383*d + 0.318717485553912*delta + 0.757256902965293*gamma],
# [  0.753511959337565*a + 0.948353049727913*alpha + 0.579300458838352*b + 0.364707412013566*beta + 0.969833254968359*c + 0.458636990859028*d + 0.291274501218671*delta + 0.56557433273608*gamma],
# [ 0.429953882321052*a + 0.228137370287734*alpha + 0.716844653579684*b + 0.466805523811737*beta + 0.354088233284079*c + 0.145947629991069*d + 0.292090260162593*delta + 0.643370534315645*gamma],
# ...

# %%
nonlinsolve(tmp, a, b, c, d, alpha, beta, gamma, delta)
# Out:
# FiniteSet((0, 0, 0, 0, 0, 0, 0, 0))

# %%
rho, phi = symbols('rho phi')
a, b, c, d = symbols('a b c d')

# %%
A=2*(a-b)
B=4*c
C=2*(a+b)-d
D=2*d

# %%
t = sqrt((A**2+B**2-A*(C+D*cos(phi/2)**2)+rho*sqrt(B**2*(A**2+B**2-(C+D*cos(phi/2)**2)**2)))/(2*(A**2+B**2)))

# %%
t.diff(phi)
# Out:
# sqrt((16*c**2 + 4*rho*sqrt(c**2*(16*c**2 + (2*a - 2*b)**2 - (2*a + 2*b + 2*d*cos(phi/2)**2 - d)**2)) + (2*a - 2*b)**2 - (2*a - 2*b)*(2*a + 2*b + 2*d*cos(phi/2)**2 - d))/(32*c**2 + 2*(2*a - 2*b)**2))*(8*d*rho*sqrt(c**2*(16*c**2 + (2*a - 2*b)**2 - (2*a + 2*b + 2*d*cos(phi/2)**2 - d)**2))*(2*a + 2*b + 2*d*cos(phi/2)**2 - d)*sin(phi/2)*cos(phi/2)/(16*c**2 + (2*a - 2*b)**2 - (2*a + 2*b + 2*d*cos(phi/2)**2 - d)**2) - 2*d*(-2*a + 2*b)*sin(phi/2)*cos(phi/2))/(2*(16*c**2 + 4*rho*sqrt(c**2*(16*c**2 + (2*a - 2*b)**2 - (2*a + 2*b + 2*d*cos(phi/2)**2 - d)**2)) + (2*a - 2*b)**2 - (2*a - 2*b)*(2*a + 2*b + 2*d*cos(phi/2)**2 - d)))

# %%
tmp = A[:4,:4]

# %%
tmp
# Out:
# Matrix([
# [rho_sigma*v,           u,                          0,                         0],
# [          u, rho_sigma*v,                          0,                         0],
# [          0,           0,            -u*exp(I*phi/2), -rho_sigma*v*exp(I*phi/2)],
# [          0,           0, -rho_sigma*v*exp(-I*phi/2),          -u*exp(-I*phi/2)]])

# %%
vec = tmp.eigenvecs()
# Out:
# --------------------------------------------------------------------------
# AttributeError                           Traceback (most recent call last)
# <ipython-input-67-e618ce183f37> in <module>
# ----> 1 vec = tmp.eigenvecs()
#
# AttributeError: 'MutableDenseMatrix' object has no attribute 'eigenvecs'

# %%
eigen_4
# Out:
# {rho_sigma*v - u: 1,
#  rho_sigma*v + u: 1,
#  -u*cos(phi/2) - sqrt(rho_sigma**2*v**2 + u**2*cos(phi/2)**2 - u**2): 1,
#  -u*cos(phi/2) + sqrt(rho_sigma**2*v**2 + u**2*cos(phi/2)**2 - u**2): 1}

# %%
tmp_5 = A[:5,:5]

# %%
tmp_5
# Out:
# Matrix([
# [                        rho_sigma*v,                         u,                          0,                         0,         -1],
# [                                  u,               rho_sigma*v,                          0,                         0,          0],
# [                                  0,                         0,            -u*exp(I*phi/2), -rho_sigma*v*exp(I*phi/2), exp(I*L*q)],
# [                                  0,                         0, -rho_sigma*v*exp(-I*phi/2),          -u*exp(-I*phi/2),          0],
# [-rho_sigma*v*(2*H/h_bar**2 + I*k/m), -u*(2*H/h_bar**2 - I*k/m),                          0,                         0,  I*q/m_bar]])
