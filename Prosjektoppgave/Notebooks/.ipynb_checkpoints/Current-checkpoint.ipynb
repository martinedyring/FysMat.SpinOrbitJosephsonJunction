# %%
import sys
from matplotlib import cm
import matplotlib.pyplot as plt
import numpy as np

sys.path.append("/Users/martinedh/Documents/NTNU/GitHub/FysMat/Prosjektoppgave")
from main import solve_and_return_system_and_F_matrix
from main import define_system, solve_and_test_small_system, solve_for_sns_system, solve_for_sfs_system
from plots import plot_pairing_amplitude, plot_density_of_states

from solve_hamiltonian import solve_system

# %% [markdown]
# <h2> Current for one system of SNS. Test to see if current is constant.
# Also: Test for runtime and convergance

# %%
# record runtime
import timeit
start = timeit.default_timer()


system, F_matrix = solve_and_test_small_system()

# print runtime
stop = timeit.default_timer()
print('Time: ', stop - start)
# Out:
# Hermition:  True
# Iteration nr. 1
# num_delta_over_tol =  10  -- where total nun lattice sites is  10
# Iteration nr. 2
# num_delta_over_tol =  10  -- where total nun lattice sites is  10
# Iteration nr. 3
# num_delta_over_tol =  10  -- where total nun lattice sites is  10
# Iteration nr. 4
# num_delta_over_tol =  10  -- where total nun lattice sites is  10
# Iteration nr. 5
# num_delta_over_tol =  10  -- where total nun lattice sites is  10
# Iteration nr. 6
# num_delta_over_tol =  10  -- where total nun lattice sites is  10
# Iteration nr. 7
# num_delta_over_tol =  10  -- where total nun lattice sites is  10
# Iteration nr. 8
# num_delta_over_tol =  10  -- where total nun lattice sites is  10
# Iteration nr. 9
# num_delta_over_tol =  10  -- where total nun lattice sites is  10
# Iteration nr. 10
# num_delta_over_tol =  10  -- where total nun lattice sites is  10
# Iteration nr. 11
# num_delta_over_tol =  10  -- where total nun lattice sites is  10
# Iteration nr. 12
# num_delta_over_tol =  10  -- where total nun lattice sites is  10
# Iteration nr. 13
# num_delta_over_tol =  10  -- where total nun lattice sites is  10
# Iteration nr. 14
# num_delta_over_tol =  10  -- where total nun lattice sites is  10
# Iteration nr. 15
# num_delta_over_tol =  10  -- where total nun lattice sites is  10
# Iteration nr. 16
# num_delta_over_tol =  10  -- where total nun lattice sites is  10
# Iteration nr. 17
# num_delta_over_tol =  10  -- where total nun lattice sites is  10
# Iteration nr. 18
# num_delta_over_tol =  10  -- where total nun lattice sites is  10
# Iteration nr. 19
# num_delta_over_tol =  10  -- where total nun lattice sites is  10
# Iteration nr. 20
# num_delta_over_tol =  10  -- where total nun lattice sites is  10
# Iteration nr. 21
# num_delta_over_tol =  10  -- where total nun lattice sites is  10
# Iteration nr. 22
# num_delta_over_tol =  10  -- where total nun lattice sites is  10
# Iteration nr. 23
# num_delta_over_tol =  10  -- where total nun lattice sites is  10
# Iteration nr. 24
# num_delta_over_tol =  10  -- where total nun lattice sites is  10
# Iteration nr. 25
# num_delta_over_tol =  10  -- where total nun lattice sites is  10
# Iteration nr. 26
# num_delta_over_tol =  10  -- where total nun lattice sites is  10
# Iteration nr. 27
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 28
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 29
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 30
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 31
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 32
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 33
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 34
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 35
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 36
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 37
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 38
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 39
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 40
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 41
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 42
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 43
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 44
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 45
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 46
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 47
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 48
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 49
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 50
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 51
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 52
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 53
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 54
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 55
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 56
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 57
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 58
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 59
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 60
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 61
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 62
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 63
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 64
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 65
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 66
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 67
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 68
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 69
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 70
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 71
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 72
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 73
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 74
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 75
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 76
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 77
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 78
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 79
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 80
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 81
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 82
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 83
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 84
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 85
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 86
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 87
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 88
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 89
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 90
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 91
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 92
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 93
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 94
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 95
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 96
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 97
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 98
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 99
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 100
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 101
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 102
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 103
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 104
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 105
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 106
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 107
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 108
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 109
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 110
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 111
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 112
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 113
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 114
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 115
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 116
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 117
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 118
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 119
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 120
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 121
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 122
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 123
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 124
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 125
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 126
# num_delta_over_tol =  8  -- where total nun lattice sites is  10
# Iteration nr. 127
# num_delta_over_tol =  6  -- where total nun lattice sites is  10
# Iteration nr. 128
# num_delta_over_tol =  6  -- where total nun lattice sites is  10
# Iteration nr. 129
# num_delta_over_tol =  6  -- where total nun lattice sites is  10
# Iteration nr. 130
# num_delta_over_tol =  6  -- where total nun lattice sites is  10
# Iteration nr. 131
# num_delta_over_tol =  6  -- where total nun lattice sites is  10
# Iteration nr. 132
# num_delta_over_tol =  6  -- where total nun lattice sites is  10
# Iteration nr. 133
# num_delta_over_tol =  6  -- where total nun lattice sites is  10
# Iteration nr. 134
# num_delta_over_tol =  6  -- where total nun lattice sites is  10
# Iteration nr. 135
# num_delta_over_tol =  6  -- where total nun lattice sites is  10
# Iteration nr. 136
# num_delta_over_tol =  6  -- where total nun lattice sites is  10
# Iteration nr. 137
# num_delta_over_tol =  6  -- where total nun lattice sites is  10
# Iteration nr. 138
# num_delta_over_tol =  4  -- where total nun lattice sites is  10
# Iteration nr. 139
# num_delta_over_tol =  4  -- where total nun lattice sites is  10
# Iteration nr. 140
# num_delta_over_tol =  4  -- where total nun lattice sites is  10
# Iteration nr. 141
# num_delta_over_tol =  2  -- where total nun lattice sites is  10
# Iteration nr. 142
# num_delta_over_tol =  2  -- where total nun lattice sites is  10
# Iteration nr. 143
# num_delta_over_tol =  0  -- where total nun lattice sites is  10
# Time:  1779.4439957730065

# %%
plot_pairing_amplitude(system, system.F_matrix) 
# it 1: diff 80.31784729526646
# it 2: diff 13.608228168595833

# %%
#current = current_along_lattice(system)

# prøv denne og se om du fremdeles får en strøm om går hardt til null i sc
current = system.current_along_lattice()

# %%
site_x = np.linspace(0, system.L_x-1, system.L_x-1)
#plt.plot(site_x, np.real(current), label="real")
plt.plot(site_x[1:], np.imag(current)[1:], label="current")
plt.legend()
plt.xlabel("lattice site [SC-SC]/[5-5]")
plt.ylabel("current I_x")
plt.grid()
plt.savefig('current_sc_tole-6_LzLy=60.png', dpi=200, bbox_inches='tight')
plt.show()

# %% [markdown]
# <h2> Given that the current is correct; create plot for current as a function of phase in SNS-system.

# %%
import sys
import numpy as np
sys.path.append("/Users/martinedh/Documents/NTNU/GitHub/FysMat/Prosjektoppgave")
from main import define_system, solve_and_test_small_system, solve_for_sns_system

# %%
current_for_phase, phase_arr = solve_for_sns_system()
# Out:
# #_________ Phase =  0.0 _________#
# Hermition:  True
# Iteration nr. 1
# Iteration nr. 2
# Iteration nr. 3
# Iteration nr. 4
# Iteration nr. 5
# Iteration nr. 6
# Iteration nr. 7
# Iteration nr. 8
# Iteration nr. 9
# #_________ Phase =  0.3306939635357677 _________#
# Hermition:  True
# Iteration nr. 1
# Iteration nr. 2
# Iteration nr. 3
# Iteration nr. 4
# Iteration nr. 5
# Iteration nr. 6
# Iteration nr. 7
# Iteration nr. 8
# Iteration nr. 9
# Iteration nr. 10
# Iteration nr. 11
# Iteration nr. 12
# Iteration nr. 13
# Iteration nr. 14
# Iteration nr. 15
# Iteration nr. 16
# Iteration nr. 17
# Iteration nr. 18
# Iteration nr. 19
# Iteration nr. 20
# Iteration nr. 21
# Iteration nr. 22
# Iteration nr. 23
# Iteration nr. 24
# Iteration nr. 25
# Iteration nr. 26
# Iteration nr. 27
# Iteration nr. 28
# Iteration nr. 29
# Iteration nr. 30
# Iteration nr. 31
# Iteration nr. 32
# Iteration nr. 33
# Iteration nr. 34
# Iteration nr. 35
# Iteration nr. 36
# Iteration nr. 37
# Iteration nr. 38
# Iteration nr. 39
# Iteration nr. 40
# Iteration nr. 41
# Iteration nr. 42
# Iteration nr. 43
# Iteration nr. 44
# Iteration nr. 45
# Iteration nr. 46
# Iteration nr. 47
# Iteration nr. 48
# Iteration nr. 49
# Iteration nr. 50
# Iteration nr. 51
# Iteration nr. 52
# Iteration nr. 53
# Iteration nr. 54
# Iteration nr. 55
# Iteration nr. 56
# Iteration nr. 57
# Iteration nr. 58
# Iteration nr. 59
# Iteration nr. 60
# Iteration nr. 61
# Iteration nr. 62
# Iteration nr. 63
# Iteration nr. 64
# Iteration nr. 65
# Iteration nr. 66
# Iteration nr. 67
# Iteration nr. 68
# Iteration nr. 69
# Iteration nr. 70
# Iteration nr. 71
# Iteration nr. 72
# Iteration nr. 73
# Iteration nr. 74
# Iteration nr. 75
# Iteration nr. 76
# Iteration nr. 77
# Iteration nr. 78
# Iteration nr. 79
# Iteration nr. 80
# Iteration nr. 81
# Iteration nr. 82
# Iteration nr. 83
# Iteration nr. 84
# Iteration nr. 85
# Iteration nr. 86
# Iteration nr. 87
# Iteration nr. 88
# Iteration nr. 89
# Iteration nr. 90
# Iteration nr. 91
# Iteration nr. 92
# Iteration nr. 93
# Iteration nr. 94
# Iteration nr. 95
# Iteration nr. 96
# Iteration nr. 97
# Iteration nr. 98
# Iteration nr. 99
# Iteration nr. 100
# Iteration nr. 101
# Iteration nr. 102
# Iteration nr. 103
# Iteration nr. 104
# Iteration nr. 105
# Iteration nr. 106
# Iteration nr. 107
# Iteration nr. 108
# Iteration nr. 109
# Iteration nr. 110
# Iteration nr. 111
# Iteration nr. 112
# Iteration nr. 113
# Iteration nr. 114
# Iteration nr. 115
# Iteration nr. 116
# Iteration nr. 117
# Iteration nr. 118
# Iteration nr. 119
# Iteration nr. 120
# Iteration nr. 121
# Iteration nr. 122
# Iteration nr. 123
# Iteration nr. 124
# Iteration nr. 125
# Iteration nr. 126
# Iteration nr. 127
# Iteration nr. 128
# Iteration nr. 129
# Iteration nr. 130
# Iteration nr. 131
# Iteration nr. 132
# Iteration nr. 133
# Iteration nr. 134
# Iteration nr. 135
# Iteration nr. 136
# Iteration nr. 137
# Iteration nr. 138
# Iteration nr. 139
# Iteration nr. 140
# Iteration nr. 141
# Iteration nr. 142
# Iteration nr. 143
# Iteration nr. 144
# Iteration nr. 145
# Iteration nr. 146
# Iteration nr. 147
# Iteration nr. 148
# Iteration nr. 149
# Iteration nr. 150
# Iteration nr. 151
# Iteration nr. 152
# Iteration nr. 153
# Iteration nr. 154
# Iteration nr. 155
# Iteration nr. 156
# Iteration nr. 157
# Iteration nr. 158
# Iteration nr. 159
# Iteration nr. 160
# Iteration nr. 161
# Iteration nr. 162
# Iteration nr. 163
# Iteration nr. 164
# Iteration nr. 165
# Iteration nr. 166
# Iteration nr. 167
# Iteration nr. 168
# Iteration nr. 169
# Iteration nr. 170
# Iteration nr. 171
# Iteration nr. 172
# Iteration nr. 173
# Iteration nr. 174
# Iteration nr. 175
# Iteration nr. 176
# Iteration nr. 177
# Iteration nr. 178
# Iteration nr. 179
# Iteration nr. 180
# Iteration nr. 181
# Iteration nr. 182
# Iteration nr. 183
# Iteration nr. 184
# Iteration nr. 185
# Iteration nr. 186
# Iteration nr. 187
# Iteration nr. 188
# Iteration nr. 189
# Iteration nr. 190
# #_________ Phase =  0.6613879270715354 _________#
# Hermition:  True
# Iteration nr. 1
# Iteration nr. 2
# Iteration nr. 3
# Iteration nr. 4
# Iteration nr. 5
# Iteration nr. 6
# Iteration nr. 7
# Iteration nr. 8
# Iteration nr. 9
# Iteration nr. 10
# Iteration nr. 11
# Iteration nr. 12
# Iteration nr. 13
# Iteration nr. 14
# Iteration nr. 15
# Iteration nr. 16
# Iteration nr. 17
# Iteration nr. 18
# Iteration nr. 19
# Iteration nr. 20
# Iteration nr. 21
# Iteration nr. 22
# Iteration nr. 23
# Iteration nr. 24
# Iteration nr. 25
# Iteration nr. 26
# Iteration nr. 27
# Iteration nr. 28
# Iteration nr. 29
# Iteration nr. 30
# Iteration nr. 31
# Iteration nr. 32
# Iteration nr. 33
# Iteration nr. 34
# Iteration nr. 35
# Iteration nr. 36
# Iteration nr. 37
# Iteration nr. 38
# Iteration nr. 39
# Iteration nr. 40
# Iteration nr. 41
# Iteration nr. 42
# Iteration nr. 43
# Iteration nr. 44
# Iteration nr. 45
# Iteration nr. 46
# Iteration nr. 47
# Iteration nr. 48
# Iteration nr. 49
# Iteration nr. 50
# Iteration nr. 51
# Iteration nr. 52
# Iteration nr. 53
# Iteration nr. 54
# Iteration nr. 55
# Iteration nr. 56
# Iteration nr. 57
# Iteration nr. 58
# Iteration nr. 59
# Iteration nr. 60
# Iteration nr. 61
# Iteration nr. 62
# Iteration nr. 63
# Iteration nr. 64
# Iteration nr. 65
# Iteration nr. 66
# Iteration nr. 67
# Iteration nr. 68
# Iteration nr. 69
# Iteration nr. 70
# Iteration nr. 71
# Iteration nr. 72
# Iteration nr. 73
# Iteration nr. 74
# Iteration nr. 75
# Iteration nr. 76
# Iteration nr. 77
# Iteration nr. 78
# Iteration nr. 79
# Iteration nr. 80
# Iteration nr. 81
# Iteration nr. 82
# Iteration nr. 83
# Iteration nr. 84
# Iteration nr. 85
# Iteration nr. 86
# Iteration nr. 87
# Iteration nr. 88
# Iteration nr. 89
# Iteration nr. 90
# Iteration nr. 91
# Iteration nr. 92
# Iteration nr. 93
# Iteration nr. 94
# Iteration nr. 95
# Iteration nr. 96
# Iteration nr. 97
# Iteration nr. 98
# Iteration nr. 99
# Iteration nr. 100
# Iteration nr. 101
# Iteration nr. 102
# Iteration nr. 103
# Iteration nr. 104
# Iteration nr. 105
# Iteration nr. 106
# Iteration nr. 107
# Iteration nr. 108
# Iteration nr. 109
# Iteration nr. 110
# Iteration nr. 111
# Iteration nr. 112
# Iteration nr. 113
# Iteration nr. 114
# Iteration nr. 115
# Iteration nr. 116
# Iteration nr. 117
# Iteration nr. 118
# Iteration nr. 119
# Iteration nr. 120
# Iteration nr. 121
# Iteration nr. 122
# Iteration nr. 123
# Iteration nr. 124
# Iteration nr. 125
# Iteration nr. 126
# Iteration nr. 127
# Iteration nr. 128
# Iteration nr. 129
# Iteration nr. 130
# Iteration nr. 131
# Iteration nr. 132
# Iteration nr. 133
# Iteration nr. 134
# Iteration nr. 135
# Iteration nr. 136
# Iteration nr. 137
# Iteration nr. 138
# Iteration nr. 139
# Iteration nr. 140
# Iteration nr. 141
# Iteration nr. 142
# Iteration nr. 143
# Iteration nr. 144
# Iteration nr. 145
# Iteration nr. 146
# Iteration nr. 147
# Iteration nr. 148
# Iteration nr. 149
# Iteration nr. 150
# Iteration nr. 151
# Iteration nr. 152
# Iteration nr. 153
# Iteration nr. 154
# Iteration nr. 155
# Iteration nr. 156
# Iteration nr. 157
# Iteration nr. 158
# Iteration nr. 159
# Iteration nr. 160
# Iteration nr. 161
# Iteration nr. 162
# Iteration nr. 163
# Iteration nr. 164
# Iteration nr. 165
# Iteration nr. 166
# Iteration nr. 167
# Iteration nr. 168
# Iteration nr. 169
# Iteration nr. 170
# Iteration nr. 171
# Iteration nr. 172
# Iteration nr. 173
# Iteration nr. 174
# Iteration nr. 175
# Iteration nr. 176
# Iteration nr. 177
# Iteration nr. 178
# Iteration nr. 179
# Iteration nr. 180
# Iteration nr. 181
# Iteration nr. 182
# Iteration nr. 183
# Iteration nr. 184
# Iteration nr. 185
# Iteration nr. 186
# Iteration nr. 187
# Iteration nr. 188
# Iteration nr. 189
# Iteration nr. 190
# Iteration nr. 191
# Iteration nr. 192
# Iteration nr. 193
# Iteration nr. 194
# Iteration nr. 195
# Iteration nr. 196
# Iteration nr. 197
# Iteration nr. 198
# Iteration nr. 199
# Iteration nr. 200
# Iteration nr. 201
# #_________ Phase =  0.992081890607303 _________#
# Hermition:  True
# Iteration nr. 1
# Iteration nr. 2
# Iteration nr. 3
# Iteration nr. 4
# Iteration nr. 5
# Iteration nr. 6
# Iteration nr. 7
# Iteration nr. 8
# Iteration nr. 9
# Iteration nr. 10
# Iteration nr. 11
# Iteration nr. 12
# Iteration nr. 13
# Iteration nr. 14
# Iteration nr. 15
# Iteration nr. 16
# Iteration nr. 17
# Iteration nr. 18
# Iteration nr. 19
# Iteration nr. 20
# Iteration nr. 21
# Iteration nr. 22
# Iteration nr. 23
# Iteration nr. 24
# Iteration nr. 25
# Iteration nr. 26
# Iteration nr. 27
# Iteration nr. 28
# Iteration nr. 29
# Iteration nr. 30
# Iteration nr. 31
# Iteration nr. 32
# Iteration nr. 33
# Iteration nr. 34
# Iteration nr. 35
# Iteration nr. 36
# Iteration nr. 37
# Iteration nr. 38
# Iteration nr. 39
# Iteration nr. 40
# Iteration nr. 41
# Iteration nr. 42
# Iteration nr. 43
# Iteration nr. 44
# Iteration nr. 45
# Iteration nr. 46
# Iteration nr. 47
# Iteration nr. 48
# Iteration nr. 49
# Iteration nr. 50
# Iteration nr. 51
# Iteration nr. 52
# Iteration nr. 53
# Iteration nr. 54
# Iteration nr. 55
# Iteration nr. 56
# Iteration nr. 57
# Iteration nr. 58
# Iteration nr. 59
# Iteration nr. 60
# Iteration nr. 61
# Iteration nr. 62
# Iteration nr. 63
# Iteration nr. 64
# Iteration nr. 65
# Iteration nr. 66
# Iteration nr. 67
# Iteration nr. 68
# Iteration nr. 69
# Iteration nr. 70
# Iteration nr. 71
# Iteration nr. 72
# Iteration nr. 73
# Iteration nr. 74
# Iteration nr. 75
# Iteration nr. 76
# Iteration nr. 77
# Iteration nr. 78
# Iteration nr. 79
# Iteration nr. 80
# Iteration nr. 81
# Iteration nr. 82
# Iteration nr. 83
# Iteration nr. 84
# Iteration nr. 85
# Iteration nr. 86
# Iteration nr. 87
# Iteration nr. 88
# Iteration nr. 89
# Iteration nr. 90
# Iteration nr. 91
# Iteration nr. 92
# Iteration nr. 93
# Iteration nr. 94
# Iteration nr. 95
# Iteration nr. 96
# Iteration nr. 97
# Iteration nr. 98
# Iteration nr. 99
# Iteration nr. 100
# Iteration nr. 101
# Iteration nr. 102
# Iteration nr. 103
# Iteration nr. 104
# Iteration nr. 105
# Iteration nr. 106
# Iteration nr. 107
# Iteration nr. 108
# Iteration nr. 109
# Iteration nr. 110
# Iteration nr. 111
# Iteration nr. 112
# Iteration nr. 113
# Iteration nr. 114
# Iteration nr. 115
# Iteration nr. 116
# Iteration nr. 117
# Iteration nr. 118
# Iteration nr. 119
# Iteration nr. 120
# Iteration nr. 121
# Iteration nr. 122
# Iteration nr. 123
# Iteration nr. 124
# Iteration nr. 125
# Iteration nr. 126
# Iteration nr. 127
# Iteration nr. 128
# Iteration nr. 129
# Iteration nr. 130
# Iteration nr. 131
# Iteration nr. 132
# Iteration nr. 133
# Iteration nr. 134
# Iteration nr. 135
# Iteration nr. 136
# Iteration nr. 137
# Iteration nr. 138
# Iteration nr. 139
# Iteration nr. 140
# Iteration nr. 141
# Iteration nr. 142
# Iteration nr. 143
# Iteration nr. 144
# Iteration nr. 145
# Iteration nr. 146
# Iteration nr. 147
# Iteration nr. 148
# Iteration nr. 149
# Iteration nr. 150
# Iteration nr. 151
# Iteration nr. 152
# Iteration nr. 153
# Iteration nr. 154
# Iteration nr. 155
# Iteration nr. 156
# Iteration nr. 157
# Iteration nr. 158
# Iteration nr. 159
# Iteration nr. 160
# Iteration nr. 161
# Iteration nr. 162
# Iteration nr. 163
# Iteration nr. 164
# Iteration nr. 165
# Iteration nr. 166
# Iteration nr. 167
# Iteration nr. 168
# Iteration nr. 169
# Iteration nr. 170
# Iteration nr. 171
# Iteration nr. 172
# Iteration nr. 173
# Iteration nr. 174
# Iteration nr. 175
# Iteration nr. 176
# Iteration nr. 177
# Iteration nr. 178
# Iteration nr. 179
# Iteration nr. 180
# Iteration nr. 181
# Iteration nr. 182
# Iteration nr. 183
# Iteration nr. 184
# Iteration nr. 185
# Iteration nr. 186
# Iteration nr. 187
# Iteration nr. 188
# Iteration nr. 189
# Iteration nr. 190
# Iteration nr. 191
# Iteration nr. 192
# Iteration nr. 193
# Iteration nr. 194
# Iteration nr. 195
# Iteration nr. 196
# Iteration nr. 197
# Iteration nr. 198
# Iteration nr. 199
# Iteration nr. 200
# Iteration nr. 201
# #_________ Phase =  1.3227758541430708 _________#
# Hermition:  True
# Iteration nr. 1
# Iteration nr. 2
# Iteration nr. 3
# Iteration nr. 4
# Iteration nr. 5
# Iteration nr. 6
# Iteration nr. 7
# Iteration nr. 8
# Iteration nr. 9
# Iteration nr. 10
# Iteration nr. 11
# Iteration nr. 12
# Iteration nr. 13
# Iteration nr. 14
# Iteration nr. 15
# Iteration nr. 16
# Iteration nr. 17
# Iteration nr. 18
# Iteration nr. 19
# Iteration nr. 20
# Iteration nr. 21
# Iteration nr. 22
# Iteration nr. 23
# Iteration nr. 24
# Iteration nr. 25
# Iteration nr. 26
# Iteration nr. 27
# Iteration nr. 28
# Iteration nr. 29
# Iteration nr. 30
# Iteration nr. 31
# Iteration nr. 32
# Iteration nr. 33
# Iteration nr. 34
# Iteration nr. 35
# Iteration nr. 36
# Iteration nr. 37
# Iteration nr. 38
# Iteration nr. 39
# Iteration nr. 40
# Iteration nr. 41
# Iteration nr. 42
# Iteration nr. 43
# Iteration nr. 44
# Iteration nr. 45
# Iteration nr. 46
# Iteration nr. 47
# Iteration nr. 48
# Iteration nr. 49
# Iteration nr. 50
# Iteration nr. 51
# Iteration nr. 52
# Iteration nr. 53
# Iteration nr. 54
# Iteration nr. 55
# Iteration nr. 56
# Iteration nr. 57
# Iteration nr. 58
# Iteration nr. 59
# Iteration nr. 60
# Iteration nr. 61
# Iteration nr. 62
# Iteration nr. 63
# Iteration nr. 64
# Iteration nr. 65
# Iteration nr. 66
# Iteration nr. 67
# Iteration nr. 68
# Iteration nr. 69
# Iteration nr. 70
# Iteration nr. 71
# Iteration nr. 72
# Iteration nr. 73
# Iteration nr. 74
# Iteration nr. 75
# Iteration nr. 76
# Iteration nr. 77
# Iteration nr. 78
# Iteration nr. 79
# Iteration nr. 80
# Iteration nr. 81
# Iteration nr. 82
# Iteration nr. 83
# Iteration nr. 84
# Iteration nr. 85
# Iteration nr. 86
# Iteration nr. 87
# Iteration nr. 88
# Iteration nr. 89
# Iteration nr. 90
# Iteration nr. 91
# Iteration nr. 92
# Iteration nr. 93
# Iteration nr. 94
# Iteration nr. 95
# Iteration nr. 96
# Iteration nr. 97
# Iteration nr. 98
# Iteration nr. 99
# Iteration nr. 100
# Iteration nr. 101
# Iteration nr. 102
# Iteration nr. 103
# Iteration nr. 104
# Iteration nr. 105
# Iteration nr. 106
# Iteration nr. 107
# Iteration nr. 108
# Iteration nr. 109
# Iteration nr. 110
# Iteration nr. 111
# Iteration nr. 112
# Iteration nr. 113
# Iteration nr. 114
# Iteration nr. 115
# Iteration nr. 116
# Iteration nr. 117
# Iteration nr. 118
# Iteration nr. 119
# Iteration nr. 120
# Iteration nr. 121
# Iteration nr. 122
# Iteration nr. 123
# Iteration nr. 124
# Iteration nr. 125
# Iteration nr. 126
# Iteration nr. 127
# Iteration nr. 128
# Iteration nr. 129
# Iteration nr. 130
# Iteration nr. 131
# Iteration nr. 132
# Iteration nr. 133
# Iteration nr. 134
# Iteration nr. 135
# Iteration nr. 136
# Iteration nr. 137
# Iteration nr. 138
# Iteration nr. 139
# Iteration nr. 140
# Iteration nr. 141
# Iteration nr. 142
# Iteration nr. 143
# Iteration nr. 144
# Iteration nr. 145
# Iteration nr. 146
# Iteration nr. 147
# Iteration nr. 148
# Iteration nr. 149
# Iteration nr. 150
# Iteration nr. 151
# Iteration nr. 152
# Iteration nr. 153
# Iteration nr. 154
# Iteration nr. 155
# Iteration nr. 156
# Iteration nr. 157
# Iteration nr. 158
# Iteration nr. 159
# Iteration nr. 160
# Iteration nr. 161
# Iteration nr. 162
# Iteration nr. 163
# Iteration nr. 164
# Iteration nr. 165
# Iteration nr. 166
# Iteration nr. 167
# Iteration nr. 168
# Iteration nr. 169
# Iteration nr. 170
# Iteration nr. 171
# Iteration nr. 172
# Iteration nr. 173
# Iteration nr. 174
# Iteration nr. 175
# Iteration nr. 176
# Iteration nr. 177
# Iteration nr. 178
# Iteration nr. 179
# Iteration nr. 180
# Iteration nr. 181
# Iteration nr. 182
# Iteration nr. 183
# Iteration nr. 184
# Iteration nr. 185
# Iteration nr. 186
# Iteration nr. 187
# Iteration nr. 188
# Iteration nr. 189
# Iteration nr. 190
# Iteration nr. 191
# Iteration nr. 192
# Iteration nr. 193
# Iteration nr. 194
# Iteration nr. 195
# Iteration nr. 196
# Iteration nr. 197
# Iteration nr. 198
# Iteration nr. 199
# Iteration nr. 200
# Iteration nr. 201
# #_________ Phase =  1.6534698176788385 _________#
# Hermition:  True
# Iteration nr. 1
# Iteration nr. 2
# Iteration nr. 3
# Iteration nr. 4
# Iteration nr. 5
# Iteration nr. 6
# Iteration nr. 7
# Iteration nr. 8
# Iteration nr. 9
# Iteration nr. 10
# Iteration nr. 11
# Iteration nr. 12
# Iteration nr. 13
# Iteration nr. 14
# Iteration nr. 15
# Iteration nr. 16
# Iteration nr. 17
# Iteration nr. 18
# Iteration nr. 19
# Iteration nr. 20
# Iteration nr. 21
# Iteration nr. 22
# Iteration nr. 23
# Iteration nr. 24
# Iteration nr. 25
# Iteration nr. 26
# Iteration nr. 27
# Iteration nr. 28
# Iteration nr. 29
# Iteration nr. 30
# Iteration nr. 31
# Iteration nr. 32
# Iteration nr. 33
# Iteration nr. 34
# Iteration nr. 35
# Iteration nr. 36
# Iteration nr. 37
# Iteration nr. 38
# Iteration nr. 39
# Iteration nr. 40
# Iteration nr. 41
# Iteration nr. 42
# Iteration nr. 43
# Iteration nr. 44
# Iteration nr. 45
# Iteration nr. 46
# Iteration nr. 47
# Iteration nr. 48
# Iteration nr. 49
# Iteration nr. 50
# Iteration nr. 51
# Iteration nr. 52
# Iteration nr. 53
# Iteration nr. 54
# Iteration nr. 55
# Iteration nr. 56
# Iteration nr. 57
# Iteration nr. 58
# Iteration nr. 59
# Iteration nr. 60
# Iteration nr. 61
# Iteration nr. 62
# Iteration nr. 63
# Iteration nr. 64
# Iteration nr. 65
# Iteration nr. 66
# Iteration nr. 67
# Iteration nr. 68
# Iteration nr. 69
# Iteration nr. 70
# Iteration nr. 71
# Iteration nr. 72
# Iteration nr. 73
# Iteration nr. 74
# Iteration nr. 75
# Iteration nr. 76
# Iteration nr. 77
# Iteration nr. 78
# Iteration nr. 79
# Iteration nr. 80
# Iteration nr. 81
# Iteration nr. 82
# Iteration nr. 83
# Iteration nr. 84
# Iteration nr. 85
# Iteration nr. 86
# Iteration nr. 87
# Iteration nr. 88
# Iteration nr. 89
# Iteration nr. 90
# Iteration nr. 91
# Iteration nr. 92
# Iteration nr. 93
# Iteration nr. 94
# Iteration nr. 95
# Iteration nr. 96
# Iteration nr. 97
# Iteration nr. 98
# Iteration nr. 99
# Iteration nr. 100
# Iteration nr. 101
# Iteration nr. 102
# Iteration nr. 103
# Iteration nr. 104
# Iteration nr. 105
# Iteration nr. 106
# Iteration nr. 107
# Iteration nr. 108
# Iteration nr. 109
# Iteration nr. 110
# Iteration nr. 111
# Iteration nr. 112
# Iteration nr. 113
# Iteration nr. 114
# Iteration nr. 115
# Iteration nr. 116
# Iteration nr. 117
# Iteration nr. 118
# Iteration nr. 119
# Iteration nr. 120
# Iteration nr. 121
# Iteration nr. 122
# Iteration nr. 123
# Iteration nr. 124
# Iteration nr. 125
# Iteration nr. 126
# Iteration nr. 127
# Iteration nr. 128
# Iteration nr. 129
# Iteration nr. 130
# Iteration nr. 131
# Iteration nr. 132
# Iteration nr. 133
# Iteration nr. 134
# Iteration nr. 135
# Iteration nr. 136
# Iteration nr. 137
# Iteration nr. 138
# Iteration nr. 139
# Iteration nr. 140
# Iteration nr. 141
# Iteration nr. 142
# Iteration nr. 143
# Iteration nr. 144
# Iteration nr. 145
# Iteration nr. 146
# Iteration nr. 147
# Iteration nr. 148
# Iteration nr. 149
# Iteration nr. 150
# Iteration nr. 151
# Iteration nr. 152
# Iteration nr. 153
# Iteration nr. 154
# Iteration nr. 155
# Iteration nr. 156
# Iteration nr. 157
# Iteration nr. 158
# Iteration nr. 159
# Iteration nr. 160
# Iteration nr. 161
# Iteration nr. 162
# Iteration nr. 163
# Iteration nr. 164
# Iteration nr. 165
# Iteration nr. 166
# Iteration nr. 167
# Iteration nr. 168
# Iteration nr. 169
# Iteration nr. 170
# Iteration nr. 171
# Iteration nr. 172
# Iteration nr. 173
# Iteration nr. 174
# Iteration nr. 175
# Iteration nr. 176
# Iteration nr. 177
# Iteration nr. 178
# Iteration nr. 179
# Iteration nr. 180
# Iteration nr. 181
# Iteration nr. 182
# Iteration nr. 183
# Iteration nr. 184
# Iteration nr. 185
# Iteration nr. 186
# Iteration nr. 187
# Iteration nr. 188
# Iteration nr. 189
# Iteration nr. 190
# Iteration nr. 191
# Iteration nr. 192
# Iteration nr. 193
# Iteration nr. 194
# Iteration nr. 195
# Iteration nr. 196
# Iteration nr. 197
# Iteration nr. 198
# Iteration nr. 199
# Iteration nr. 200
# Iteration nr. 201
# #_________ Phase =  1.984163781214606 _________#
# Hermition:  True
# Iteration nr. 1
# Iteration nr. 2
# Iteration nr. 3
# Iteration nr. 4
# Iteration nr. 5
# Iteration nr. 6
# Iteration nr. 7
# Iteration nr. 8
# Iteration nr. 9
# Iteration nr. 10
# Iteration nr. 11
# Iteration nr. 12
# Iteration nr. 13
# Iteration nr. 14
# Iteration nr. 15
# Iteration nr. 16
# Iteration nr. 17
# Iteration nr. 18
# Iteration nr. 19
# Iteration nr. 20
# Iteration nr. 21
# Iteration nr. 22
# Iteration nr. 23
# Iteration nr. 24
# Iteration nr. 25
# Iteration nr. 26
# Iteration nr. 27
# Iteration nr. 28
# Iteration nr. 29
# Iteration nr. 30
# Iteration nr. 31
# Iteration nr. 32
# Iteration nr. 33
# Iteration nr. 34
# Iteration nr. 35
# Iteration nr. 36
# Iteration nr. 37
# Iteration nr. 38
# Iteration nr. 39
# Iteration nr. 40
# Iteration nr. 41
# Iteration nr. 42
# Iteration nr. 43
# Iteration nr. 44
# Iteration nr. 45
# Iteration nr. 46
# Iteration nr. 47
# Iteration nr. 48
# Iteration nr. 49
# Iteration nr. 50
# Iteration nr. 51
# Iteration nr. 52
# Iteration nr. 53
# Iteration nr. 54
# Iteration nr. 55
# Iteration nr. 56
# Iteration nr. 57
# Iteration nr. 58
# Iteration nr. 59
# Iteration nr. 60
# Iteration nr. 61
# Iteration nr. 62
# Iteration nr. 63
# Iteration nr. 64
# Iteration nr. 65
# Iteration nr. 66
# Iteration nr. 67
# Iteration nr. 68
# Iteration nr. 69
# Iteration nr. 70
# Iteration nr. 71
# Iteration nr. 72
# Iteration nr. 73
# Iteration nr. 74
# Iteration nr. 75
# Iteration nr. 76
# Iteration nr. 77
# Iteration nr. 78
# Iteration nr. 79
# Iteration nr. 80
# Iteration nr. 81
# Iteration nr. 82
# Iteration nr. 83
# Iteration nr. 84
# Iteration nr. 85
# Iteration nr. 86
# Iteration nr. 87
# Iteration nr. 88
# Iteration nr. 89
# Iteration nr. 90
# Iteration nr. 91
# Iteration nr. 92
# Iteration nr. 93
# Iteration nr. 94
# Iteration nr. 95
# Iteration nr. 96
# Iteration nr. 97
# Iteration nr. 98
# Iteration nr. 99
# Iteration nr. 100
# Iteration nr. 101
# Iteration nr. 102
# Iteration nr. 103
# Iteration nr. 104
# Iteration nr. 105
# Iteration nr. 106
# Iteration nr. 107
# Iteration nr. 108
# Iteration nr. 109
# Iteration nr. 110
# Iteration nr. 111
# Iteration nr. 112
# Iteration nr. 113
# Iteration nr. 114
# Iteration nr. 115
# Iteration nr. 116
# Iteration nr. 117
# Iteration nr. 118
# Iteration nr. 119
# Iteration nr. 120
# Iteration nr. 121
# Iteration nr. 122
# Iteration nr. 123
# Iteration nr. 124
# Iteration nr. 125
# Iteration nr. 126
# Iteration nr. 127
# Iteration nr. 128
# Iteration nr. 129
# Iteration nr. 130
# Iteration nr. 131
# Iteration nr. 132
# Iteration nr. 133
# Iteration nr. 134
# Iteration nr. 135
# Iteration nr. 136
# Iteration nr. 137
# Iteration nr. 138
# Iteration nr. 139
# Iteration nr. 140
# Iteration nr. 141
# Iteration nr. 142
# Iteration nr. 143
# Iteration nr. 144
# Iteration nr. 145
# Iteration nr. 146
# Iteration nr. 147
# Iteration nr. 148
# Iteration nr. 149
# Iteration nr. 150
# Iteration nr. 151
# Iteration nr. 152
# Iteration nr. 153
# Iteration nr. 154
# Iteration nr. 155
# Iteration nr. 156
# Iteration nr. 157
# Iteration nr. 158
# Iteration nr. 159
# Iteration nr. 160
# Iteration nr. 161
# Iteration nr. 162
# Iteration nr. 163
# Iteration nr. 164
# Iteration nr. 165
# Iteration nr. 166
# Iteration nr. 167
# Iteration nr. 168
# Iteration nr. 169
# Iteration nr. 170
# Iteration nr. 171
# Iteration nr. 172
# Iteration nr. 173
# Iteration nr. 174
# Iteration nr. 175
# Iteration nr. 176
# Iteration nr. 177
# Iteration nr. 178
# Iteration nr. 179
# Iteration nr. 180
# Iteration nr. 181
# Iteration nr. 182
# Iteration nr. 183
# Iteration nr. 184
# Iteration nr. 185
# Iteration nr. 186
# Iteration nr. 187
# Iteration nr. 188
# Iteration nr. 189
# Iteration nr. 190
# Iteration nr. 191
# Iteration nr. 192
# Iteration nr. 193
# Iteration nr. 194
# Iteration nr. 195
# Iteration nr. 196
# Iteration nr. 197
# Iteration nr. 198
# Iteration nr. 199
# Iteration nr. 200
# Iteration nr. 201
# #_________ Phase =  2.3148577447503738 _________#
# Hermition:  True
# Iteration nr. 1
# Iteration nr. 2
# Iteration nr. 3
# Iteration nr. 4
# Iteration nr. 5
# Iteration nr. 6
# Iteration nr. 7
# Iteration nr. 8
# Iteration nr. 9
# Iteration nr. 10
# Iteration nr. 11
# Iteration nr. 12
# Iteration nr. 13
# Iteration nr. 14
# Iteration nr. 15
# Iteration nr. 16
# Iteration nr. 17
# Iteration nr. 18
# Iteration nr. 19
# Iteration nr. 20
# Iteration nr. 21
# Iteration nr. 22
# Iteration nr. 23
# Iteration nr. 24
# Iteration nr. 25
# Iteration nr. 26
# Iteration nr. 27
# Iteration nr. 28
# Iteration nr. 29
# Iteration nr. 30
# Iteration nr. 31
# Iteration nr. 32
# Iteration nr. 33
# Iteration nr. 34
# Iteration nr. 35
# Iteration nr. 36
# Iteration nr. 37
# Iteration nr. 38
# Iteration nr. 39
# Iteration nr. 40
# Iteration nr. 41
# Iteration nr. 42
# Iteration nr. 43
# Iteration nr. 44
# Iteration nr. 45
# Iteration nr. 46
# Iteration nr. 47
# Iteration nr. 48
# Iteration nr. 49
# Iteration nr. 50
# Iteration nr. 51
# Iteration nr. 52
# Iteration nr. 53
# Iteration nr. 54
# Iteration nr. 55
# Iteration nr. 56
# Iteration nr. 57
# Iteration nr. 58
# Iteration nr. 59
# Iteration nr. 60
# Iteration nr. 61
# Iteration nr. 62
# Iteration nr. 63
# Iteration nr. 64
# Iteration nr. 65
# Iteration nr. 66
# Iteration nr. 67
# Iteration nr. 68
# Iteration nr. 69
# Iteration nr. 70
# Iteration nr. 71
# Iteration nr. 72
# Iteration nr. 73
# Iteration nr. 74
# Iteration nr. 75
# Iteration nr. 76
# Iteration nr. 77
# Iteration nr. 78
# Iteration nr. 79
# Iteration nr. 80
# Iteration nr. 81
# Iteration nr. 82
# Iteration nr. 83
# Iteration nr. 84
# Iteration nr. 85
# Iteration nr. 86
# Iteration nr. 87
# Iteration nr. 88
# Iteration nr. 89
# Iteration nr. 90
# Iteration nr. 91
# Iteration nr. 92
# Iteration nr. 93
# Iteration nr. 94
# Iteration nr. 95
# Iteration nr. 96
# Iteration nr. 97
# Iteration nr. 98
# Iteration nr. 99
# Iteration nr. 100
# Iteration nr. 101
# Iteration nr. 102
# Iteration nr. 103
# Iteration nr. 104
# Iteration nr. 105
# Iteration nr. 106
# Iteration nr. 107
# Iteration nr. 108
# Iteration nr. 109
# Iteration nr. 110
# Iteration nr. 111
# Iteration nr. 112
# Iteration nr. 113
# Iteration nr. 114
# Iteration nr. 115
# Iteration nr. 116
# Iteration nr. 117
# Iteration nr. 118
# Iteration nr. 119
# Iteration nr. 120
# Iteration nr. 121
# Iteration nr. 122
# Iteration nr. 123
# Iteration nr. 124
# Iteration nr. 125
# Iteration nr. 126
# Iteration nr. 127
# Iteration nr. 128
# Iteration nr. 129
# Iteration nr. 130
# Iteration nr. 131
# Iteration nr. 132
# Iteration nr. 133
# Iteration nr. 134
# Iteration nr. 135
# Iteration nr. 136
# Iteration nr. 137
# Iteration nr. 138
# Iteration nr. 139
# Iteration nr. 140
# Iteration nr. 141
# Iteration nr. 142
# Iteration nr. 143
# Iteration nr. 144
# Iteration nr. 145
# Iteration nr. 146
# Iteration nr. 147
# Iteration nr. 148
# Iteration nr. 149
# Iteration nr. 150
# Iteration nr. 151
# Iteration nr. 152
# Iteration nr. 153
# Iteration nr. 154
# Iteration nr. 155
# Iteration nr. 156
# Iteration nr. 157
# Iteration nr. 158
# Iteration nr. 159
# Iteration nr. 160
# Iteration nr. 161
# Iteration nr. 162
# Iteration nr. 163
# Iteration nr. 164
# Iteration nr. 165
# Iteration nr. 166
# Iteration nr. 167
# Iteration nr. 168
# Iteration nr. 169
# Iteration nr. 170
# Iteration nr. 171
# Iteration nr. 172
# Iteration nr. 173
# Iteration nr. 174
# Iteration nr. 175
# Iteration nr. 176
# Iteration nr. 177
# Iteration nr. 178
# Iteration nr. 179
# Iteration nr. 180
# Iteration nr. 181
# Iteration nr. 182
# Iteration nr. 183
# Iteration nr. 184
# Iteration nr. 185
# Iteration nr. 186
# Iteration nr. 187
# Iteration nr. 188
# Iteration nr. 189
# Iteration nr. 190
# Iteration nr. 191
# Iteration nr. 192
# Iteration nr. 193
# Iteration nr. 194
# Iteration nr. 195
# Iteration nr. 196
# Iteration nr. 197
# Iteration nr. 198
# Iteration nr. 199
# Iteration nr. 200
# Iteration nr. 201
# #_________ Phase =  2.6455517082861415 _________#
# Hermition:  True
# Iteration nr. 1
# Iteration nr. 2
# Iteration nr. 3
# Iteration nr. 4
# Iteration nr. 5
# Iteration nr. 6
# Iteration nr. 7
# Iteration nr. 8
# Iteration nr. 9
# Iteration nr. 10
# Iteration nr. 11
# Iteration nr. 12
# Iteration nr. 13
# Iteration nr. 14
# Iteration nr. 15
# Iteration nr. 16
# Iteration nr. 17
# Iteration nr. 18
# Iteration nr. 19
# Iteration nr. 20
# Iteration nr. 21
# Iteration nr. 22
# Iteration nr. 23
# Iteration nr. 24
# Iteration nr. 25
# Iteration nr. 26
# Iteration nr. 27
# Iteration nr. 28
# Iteration nr. 29
# Iteration nr. 30
# Iteration nr. 31
# Iteration nr. 32
# Iteration nr. 33
# Iteration nr. 34
# Iteration nr. 35
# Iteration nr. 36
# Iteration nr. 37
# Iteration nr. 38
# Iteration nr. 39
# Iteration nr. 40
# Iteration nr. 41
# Iteration nr. 42
# Iteration nr. 43
# Iteration nr. 44
# Iteration nr. 45
# Iteration nr. 46
# Iteration nr. 47
# Iteration nr. 48
# Iteration nr. 49
# Iteration nr. 50
# Iteration nr. 51
# Iteration nr. 52
# Iteration nr. 53
# Iteration nr. 54
# Iteration nr. 55
# Iteration nr. 56
# Iteration nr. 57
# Iteration nr. 58
# Iteration nr. 59
# Iteration nr. 60
# Iteration nr. 61
# Iteration nr. 62
# Iteration nr. 63
# Iteration nr. 64
# Iteration nr. 65
# Iteration nr. 66
# Iteration nr. 67
# Iteration nr. 68
# Iteration nr. 69
# Iteration nr. 70
# Iteration nr. 71
# Iteration nr. 72
# Iteration nr. 73
# Iteration nr. 74
# Iteration nr. 75
# Iteration nr. 76
# Iteration nr. 77
# Iteration nr. 78
# Iteration nr. 79
# Iteration nr. 80
# Iteration nr. 81
# Iteration nr. 82
# Iteration nr. 83
# Iteration nr. 84
# Iteration nr. 85
# Iteration nr. 86
# Iteration nr. 87
# Iteration nr. 88
# Iteration nr. 89
# Iteration nr. 90
# Iteration nr. 91
# Iteration nr. 92
# Iteration nr. 93
# Iteration nr. 94
# Iteration nr. 95
# Iteration nr. 96
# Iteration nr. 97
# Iteration nr. 98
# Iteration nr. 99
# Iteration nr. 100
# Iteration nr. 101
# Iteration nr. 102
# Iteration nr. 103
# Iteration nr. 104
# Iteration nr. 105
# Iteration nr. 106
# Iteration nr. 107
# Iteration nr. 108
# Iteration nr. 109
# Iteration nr. 110
# Iteration nr. 111
# Iteration nr. 112
# Iteration nr. 113
# Iteration nr. 114
# Iteration nr. 115
# Iteration nr. 116
# Iteration nr. 117
# Iteration nr. 118
# Iteration nr. 119
# Iteration nr. 120
# Iteration nr. 121
# Iteration nr. 122
# Iteration nr. 123
# Iteration nr. 124
# Iteration nr. 125
# Iteration nr. 126
# Iteration nr. 127
# Iteration nr. 128
# Iteration nr. 129
# Iteration nr. 130
# Iteration nr. 131
# Iteration nr. 132
# Iteration nr. 133
# Iteration nr. 134
# Iteration nr. 135
# Iteration nr. 136
# Iteration nr. 137
# Iteration nr. 138
# Iteration nr. 139
# Iteration nr. 140
# Iteration nr. 141
# Iteration nr. 142
# Iteration nr. 143
# Iteration nr. 144
# Iteration nr. 145
# Iteration nr. 146
# Iteration nr. 147
# Iteration nr. 148
# Iteration nr. 149
# Iteration nr. 150
# Iteration nr. 151
# Iteration nr. 152
# Iteration nr. 153
# Iteration nr. 154
# Iteration nr. 155
# Iteration nr. 156
# Iteration nr. 157
# Iteration nr. 158
# Iteration nr. 159
# Iteration nr. 160
# Iteration nr. 161
# Iteration nr. 162
# Iteration nr. 163
# Iteration nr. 164
# Iteration nr. 165
# Iteration nr. 166
# Iteration nr. 167
# Iteration nr. 168
# Iteration nr. 169
# Iteration nr. 170
# Iteration nr. 171
# Iteration nr. 172
# Iteration nr. 173
# Iteration nr. 174
# Iteration nr. 175
# Iteration nr. 176
# Iteration nr. 177
# Iteration nr. 178
# Iteration nr. 179
# Iteration nr. 180
# Iteration nr. 181
# Iteration nr. 182
# Iteration nr. 183
# Iteration nr. 184
# Iteration nr. 185
# Iteration nr. 186
# Iteration nr. 187
# Iteration nr. 188
# Iteration nr. 189
# Iteration nr. 190
# Iteration nr. 191
# Iteration nr. 192
# Iteration nr. 193
# Iteration nr. 194
# Iteration nr. 195
# Iteration nr. 196
# Iteration nr. 197
# Iteration nr. 198
# Iteration nr. 199
# Iteration nr. 200
# Iteration nr. 201
# #_________ Phase =  2.9762456718219092 _________#
# Hermition:  True
# Iteration nr. 1
# Iteration nr. 2
# Iteration nr. 3
# Iteration nr. 4
# Iteration nr. 5
# Iteration nr. 6
# Iteration nr. 7
# Iteration nr. 8
# Iteration nr. 9
# Iteration nr. 10
# Iteration nr. 11
# Iteration nr. 12
# Iteration nr. 13
# Iteration nr. 14
# Iteration nr. 15
# Iteration nr. 16
# Iteration nr. 17
# Iteration nr. 18
# Iteration nr. 19
# Iteration nr. 20
# Iteration nr. 21
# Iteration nr. 22
# Iteration nr. 23
# Iteration nr. 24
# Iteration nr. 25
# Iteration nr. 26
# Iteration nr. 27
# Iteration nr. 28
# Iteration nr. 29
# Iteration nr. 30
# Iteration nr. 31
# Iteration nr. 32
# Iteration nr. 33
# Iteration nr. 34
# Iteration nr. 35
# Iteration nr. 36
# Iteration nr. 37
# Iteration nr. 38
# Iteration nr. 39
# Iteration nr. 40
# Iteration nr. 41
# Iteration nr. 42
# Iteration nr. 43
# Iteration nr. 44
# Iteration nr. 45
# Iteration nr. 46
# Iteration nr. 47
# Iteration nr. 48
# Iteration nr. 49
# Iteration nr. 50
# Iteration nr. 51
# Iteration nr. 52
# Iteration nr. 53
# Iteration nr. 54
# Iteration nr. 55
# Iteration nr. 56
# Iteration nr. 57
# Iteration nr. 58
# Iteration nr. 59
# Iteration nr. 60
# Iteration nr. 61
# Iteration nr. 62
# Iteration nr. 63
# Iteration nr. 64
# Iteration nr. 65
# Iteration nr. 66
# Iteration nr. 67
# Iteration nr. 68
# Iteration nr. 69
# Iteration nr. 70
# Iteration nr. 71
# Iteration nr. 72
# Iteration nr. 73
# Iteration nr. 74
# Iteration nr. 75
# Iteration nr. 76
# Iteration nr. 77
# Iteration nr. 78
# Iteration nr. 79
# Iteration nr. 80
# Iteration nr. 81
# Iteration nr. 82
# Iteration nr. 83
# Iteration nr. 84
# Iteration nr. 85
# Iteration nr. 86
# Iteration nr. 87
# Iteration nr. 88
# Iteration nr. 89
# Iteration nr. 90
# Iteration nr. 91
# Iteration nr. 92
# Iteration nr. 93
# Iteration nr. 94
# Iteration nr. 95
# Iteration nr. 96
# Iteration nr. 97
# Iteration nr. 98
# Iteration nr. 99
# Iteration nr. 100
# Iteration nr. 101
# Iteration nr. 102
# Iteration nr. 103
# Iteration nr. 104
# Iteration nr. 105
# Iteration nr. 106
# Iteration nr. 107
# Iteration nr. 108
# Iteration nr. 109
# Iteration nr. 110
# Iteration nr. 111
# Iteration nr. 112
# Iteration nr. 113
# Iteration nr. 114
# Iteration nr. 115
# Iteration nr. 116
# Iteration nr. 117
# Iteration nr. 118
# Iteration nr. 119
# Iteration nr. 120
# Iteration nr. 121
# Iteration nr. 122
# Iteration nr. 123
# Iteration nr. 124
# Iteration nr. 125
# Iteration nr. 126
# Iteration nr. 127
# Iteration nr. 128
# Iteration nr. 129
# Iteration nr. 130
# Iteration nr. 131
# Iteration nr. 132
# Iteration nr. 133
# Iteration nr. 134
# Iteration nr. 135
# Iteration nr. 136
# Iteration nr. 137
# Iteration nr. 138
# Iteration nr. 139
# Iteration nr. 140
# Iteration nr. 141
# Iteration nr. 142
# Iteration nr. 143
# Iteration nr. 144
# Iteration nr. 145
# Iteration nr. 146
# Iteration nr. 147
# Iteration nr. 148
# Iteration nr. 149
# Iteration nr. 150
# Iteration nr. 151
# Iteration nr. 152
# Iteration nr. 153
# Iteration nr. 154
# Iteration nr. 155
# Iteration nr. 156
# Iteration nr. 157
# Iteration nr. 158
# Iteration nr. 159
# Iteration nr. 160
# Iteration nr. 161
# Iteration nr. 162
# Iteration nr. 163
# Iteration nr. 164
# Iteration nr. 165
# Iteration nr. 166
# Iteration nr. 167
# Iteration nr. 168
# Iteration nr. 169
# Iteration nr. 170
# Iteration nr. 171
# Iteration nr. 172
# Iteration nr. 173
# Iteration nr. 174
# Iteration nr. 175
# Iteration nr. 176
# Iteration nr. 177
# Iteration nr. 178
# Iteration nr. 179
# Iteration nr. 180
# Iteration nr. 181
# Iteration nr. 182
# Iteration nr. 183
# Iteration nr. 184
# Iteration nr. 185
# Iteration nr. 186
# Iteration nr. 187
# Iteration nr. 188
# Iteration nr. 189
# Iteration nr. 190
# Iteration nr. 191
# Iteration nr. 192
# Iteration nr. 193
# Iteration nr. 194
# Iteration nr. 195
# Iteration nr. 196
# Iteration nr. 197
# Iteration nr. 198
# Iteration nr. 199
# Iteration nr. 200
# Iteration nr. 201
# #_________ Phase =  3.306939635357677 _________#
# Hermition:  True
# Iteration nr. 1
# Iteration nr. 2
# Iteration nr. 3
# Iteration nr. 4
# Iteration nr. 5
# Iteration nr. 6
# Iteration nr. 7
# Iteration nr. 8
# Iteration nr. 9
# Iteration nr. 10
# Iteration nr. 11
# Iteration nr. 12
# Iteration nr. 13
# Iteration nr. 14
# Iteration nr. 15
# Iteration nr. 16
# Iteration nr. 17
# Iteration nr. 18
# Iteration nr. 19
# Iteration nr. 20
# Iteration nr. 21
# Iteration nr. 22
# Iteration nr. 23
# Iteration nr. 24
# Iteration nr. 25
# Iteration nr. 26
# Iteration nr. 27
# Iteration nr. 28
# Iteration nr. 29
# Iteration nr. 30
# Iteration nr. 31
# Iteration nr. 32
# Iteration nr. 33
# Iteration nr. 34
# Iteration nr. 35
# Iteration nr. 36
# Iteration nr. 37
# Iteration nr. 38
# Iteration nr. 39
# Iteration nr. 40
# Iteration nr. 41
# Iteration nr. 42
# Iteration nr. 43
# Iteration nr. 44
# Iteration nr. 45
# Iteration nr. 46
# Iteration nr. 47
# Iteration nr. 48
# Iteration nr. 49
# Iteration nr. 50
# Iteration nr. 51
# Iteration nr. 52
# Iteration nr. 53
# Iteration nr. 54
# Iteration nr. 55
# Iteration nr. 56
# Iteration nr. 57
# Iteration nr. 58
# Iteration nr. 59
# Iteration nr. 60
# Iteration nr. 61
# Iteration nr. 62
# Iteration nr. 63
# Iteration nr. 64
# Iteration nr. 65
# Iteration nr. 66
# Iteration nr. 67
# Iteration nr. 68
# Iteration nr. 69
# Iteration nr. 70
# Iteration nr. 71
# Iteration nr. 72
# Iteration nr. 73
# Iteration nr. 74
# Iteration nr. 75
# Iteration nr. 76
# Iteration nr. 77
# Iteration nr. 78
# Iteration nr. 79
# Iteration nr. 80
# Iteration nr. 81
# Iteration nr. 82
# Iteration nr. 83
# Iteration nr. 84
# Iteration nr. 85
# Iteration nr. 86
# Iteration nr. 87
# Iteration nr. 88
# Iteration nr. 89
# Iteration nr. 90
# Iteration nr. 91
# Iteration nr. 92
# Iteration nr. 93
# Iteration nr. 94
# Iteration nr. 95
# Iteration nr. 96
# Iteration nr. 97
# Iteration nr. 98
# Iteration nr. 99
# Iteration nr. 100
# Iteration nr. 101
# Iteration nr. 102
# Iteration nr. 103
# Iteration nr. 104
# Iteration nr. 105
# Iteration nr. 106
# Iteration nr. 107
# Iteration nr. 108
# Iteration nr. 109
# Iteration nr. 110
# Iteration nr. 111
# Iteration nr. 112
# Iteration nr. 113
# Iteration nr. 114
# Iteration nr. 115
# Iteration nr. 116
# Iteration nr. 117
# Iteration nr. 118
# Iteration nr. 119
# Iteration nr. 120
# Iteration nr. 121
# Iteration nr. 122
# Iteration nr. 123
# Iteration nr. 124
# Iteration nr. 125
# Iteration nr. 126
# Iteration nr. 127
# Iteration nr. 128
# Iteration nr. 129
# Iteration nr. 130
# Iteration nr. 131
# Iteration nr. 132
# Iteration nr. 133
# Iteration nr. 134
# Iteration nr. 135
# Iteration nr. 136
# Iteration nr. 137
# Iteration nr. 138
# Iteration nr. 139
# Iteration nr. 140
# Iteration nr. 141
# Iteration nr. 142
# Iteration nr. 143
# Iteration nr. 144
# Iteration nr. 145
# Iteration nr. 146
# Iteration nr. 147
# Iteration nr. 148
# Iteration nr. 149
# Iteration nr. 150
# Iteration nr. 151
# Iteration nr. 152
# Iteration nr. 153
# Iteration nr. 154
# Iteration nr. 155
# Iteration nr. 156
# Iteration nr. 157
# Iteration nr. 158
# Iteration nr. 159
# Iteration nr. 160
# Iteration nr. 161
# Iteration nr. 162
# Iteration nr. 163
# Iteration nr. 164
# Iteration nr. 165
# Iteration nr. 166
# Iteration nr. 167
# Iteration nr. 168
# Iteration nr. 169
# Iteration nr. 170
# Iteration nr. 171
# Iteration nr. 172
# Iteration nr. 173
# Iteration nr. 174
# Iteration nr. 175
# Iteration nr. 176
# Iteration nr. 177
# Iteration nr. 178
# Iteration nr. 179
# Iteration nr. 180
# Iteration nr. 181
# Iteration nr. 182
# Iteration nr. 183
# Iteration nr. 184
# Iteration nr. 185
# Iteration nr. 186
# Iteration nr. 187
# Iteration nr. 188
# Iteration nr. 189
# Iteration nr. 190
# Iteration nr. 191
# Iteration nr. 192
# Iteration nr. 193
# Iteration nr. 194
# Iteration nr. 195
# Iteration nr. 196
# Iteration nr. 197
# Iteration nr. 198
# Iteration nr. 199
# Iteration nr. 200
# Iteration nr. 201
# #_________ Phase =  3.6376335988934447 _________#
# Hermition:  True
# Iteration nr. 1
# Iteration nr. 2
# Iteration nr. 3
# Iteration nr. 4
# Iteration nr. 5
# Iteration nr. 6
# Iteration nr. 7
# Iteration nr. 8
# Iteration nr. 9
# Iteration nr. 10
# Iteration nr. 11
# Iteration nr. 12
# Iteration nr. 13
# Iteration nr. 14
# Iteration nr. 15
# Iteration nr. 16
# Iteration nr. 17
# Iteration nr. 18
# Iteration nr. 19
# Iteration nr. 20
# Iteration nr. 21
# Iteration nr. 22
# Iteration nr. 23
# Iteration nr. 24
# Iteration nr. 25
# Iteration nr. 26
# Iteration nr. 27
# Iteration nr. 28
# Iteration nr. 29
# Iteration nr. 30
# Iteration nr. 31
# Iteration nr. 32
# Iteration nr. 33
# Iteration nr. 34
# Iteration nr. 35
# Iteration nr. 36
# Iteration nr. 37
# Iteration nr. 38
# Iteration nr. 39
# Iteration nr. 40
# Iteration nr. 41
# Iteration nr. 42
# Iteration nr. 43
# Iteration nr. 44
# Iteration nr. 45
# Iteration nr. 46
# Iteration nr. 47
# Iteration nr. 48
# Iteration nr. 49
# Iteration nr. 50
# Iteration nr. 51
# Iteration nr. 52
# Iteration nr. 53
# Iteration nr. 54
# Iteration nr. 55
# Iteration nr. 56
# Iteration nr. 57
# Iteration nr. 58
# Iteration nr. 59
# Iteration nr. 60
# Iteration nr. 61
# Iteration nr. 62
# Iteration nr. 63
# Iteration nr. 64
# Iteration nr. 65
# Iteration nr. 66
# Iteration nr. 67
# Iteration nr. 68
# Iteration nr. 69
# Iteration nr. 70
# Iteration nr. 71
# Iteration nr. 72
# Iteration nr. 73
# Iteration nr. 74
# Iteration nr. 75
# Iteration nr. 76
# Iteration nr. 77
# Iteration nr. 78
# Iteration nr. 79
# Iteration nr. 80
# Iteration nr. 81
# Iteration nr. 82
# Iteration nr. 83
# Iteration nr. 84
# Iteration nr. 85
# Iteration nr. 86
# Iteration nr. 87
# Iteration nr. 88
# Iteration nr. 89
# Iteration nr. 90
# Iteration nr. 91
# Iteration nr. 92
# Iteration nr. 93
# Iteration nr. 94
# Iteration nr. 95
# Iteration nr. 96
# Iteration nr. 97
# Iteration nr. 98
# Iteration nr. 99
# Iteration nr. 100
# Iteration nr. 101
# Iteration nr. 102
# Iteration nr. 103
# Iteration nr. 104
# Iteration nr. 105
# Iteration nr. 106
# Iteration nr. 107
# Iteration nr. 108
# Iteration nr. 109
# Iteration nr. 110
# Iteration nr. 111
# Iteration nr. 112
# Iteration nr. 113
# Iteration nr. 114
# Iteration nr. 115
# Iteration nr. 116
# Iteration nr. 117
# Iteration nr. 118
# Iteration nr. 119
# Iteration nr. 120
# Iteration nr. 121
# Iteration nr. 122
# Iteration nr. 123
# Iteration nr. 124
# Iteration nr. 125
# Iteration nr. 126
# Iteration nr. 127
# Iteration nr. 128
# Iteration nr. 129
# Iteration nr. 130
# Iteration nr. 131
# Iteration nr. 132
# Iteration nr. 133
# Iteration nr. 134
# Iteration nr. 135
# Iteration nr. 136
# Iteration nr. 137
# Iteration nr. 138
# Iteration nr. 139
# Iteration nr. 140
# Iteration nr. 141
# Iteration nr. 142
# Iteration nr. 143
# Iteration nr. 144
# Iteration nr. 145
# Iteration nr. 146
# Iteration nr. 147
# Iteration nr. 148
# Iteration nr. 149
# Iteration nr. 150
# Iteration nr. 151
# Iteration nr. 152
# Iteration nr. 153
# Iteration nr. 154
# Iteration nr. 155
# Iteration nr. 156
# Iteration nr. 157
# Iteration nr. 158
# Iteration nr. 159
# Iteration nr. 160
# Iteration nr. 161
# Iteration nr. 162
# Iteration nr. 163
# Iteration nr. 164
# Iteration nr. 165
# Iteration nr. 166
# Iteration nr. 167
# Iteration nr. 168
# Iteration nr. 169
# Iteration nr. 170
# Iteration nr. 171
# Iteration nr. 172
# Iteration nr. 173
# Iteration nr. 174
# Iteration nr. 175
# Iteration nr. 176
# Iteration nr. 177
# Iteration nr. 178
# Iteration nr. 179
# Iteration nr. 180
# Iteration nr. 181
# Iteration nr. 182
# Iteration nr. 183
# Iteration nr. 184
# Iteration nr. 185
# Iteration nr. 186
# Iteration nr. 187
# Iteration nr. 188
# Iteration nr. 189
# Iteration nr. 190
# Iteration nr. 191
# Iteration nr. 192
# Iteration nr. 193
# Iteration nr. 194
# Iteration nr. 195
# Iteration nr. 196
# Iteration nr. 197
# Iteration nr. 198
# Iteration nr. 199
# Iteration nr. 200
# Iteration nr. 201
# #_________ Phase =  3.968327562429212 _________#
# Hermition:  True
# Iteration nr. 1
# Iteration nr. 2
# Iteration nr. 3
# Iteration nr. 4
# Iteration nr. 5
# Iteration nr. 6
# Iteration nr. 7
# Iteration nr. 8
# Iteration nr. 9
# Iteration nr. 10
# Iteration nr. 11
# Iteration nr. 12
# Iteration nr. 13
# Iteration nr. 14
# Iteration nr. 15
# Iteration nr. 16
# Iteration nr. 17
# Iteration nr. 18
# Iteration nr. 19
# Iteration nr. 20
# Iteration nr. 21
# Iteration nr. 22
# Iteration nr. 23
# Iteration nr. 24
# Iteration nr. 25
# Iteration nr. 26
# Iteration nr. 27
# Iteration nr. 28
# Iteration nr. 29
# Iteration nr. 30
# Iteration nr. 31
# Iteration nr. 32
# Iteration nr. 33
# Iteration nr. 34
# Iteration nr. 35
# Iteration nr. 36
# Iteration nr. 37
# Iteration nr. 38
# Iteration nr. 39
# Iteration nr. 40
# Iteration nr. 41
# Iteration nr. 42
# Iteration nr. 43
# Iteration nr. 44
# Iteration nr. 45
# Iteration nr. 46
# Iteration nr. 47
# Iteration nr. 48
# Iteration nr. 49
# Iteration nr. 50
# Iteration nr. 51
# Iteration nr. 52
# Iteration nr. 53
# Iteration nr. 54
# Iteration nr. 55
# Iteration nr. 56
# Iteration nr. 57
# Iteration nr. 58
# Iteration nr. 59
# Iteration nr. 60
# Iteration nr. 61
# Iteration nr. 62
# Iteration nr. 63
# Iteration nr. 64
# Iteration nr. 65
# Iteration nr. 66
# Iteration nr. 67
# Iteration nr. 68
# Iteration nr. 69
# Iteration nr. 70
# Iteration nr. 71
# Iteration nr. 72
# Iteration nr. 73
# Iteration nr. 74
# Iteration nr. 75
# Iteration nr. 76
# Iteration nr. 77
# Iteration nr. 78
# Iteration nr. 79
# Iteration nr. 80
# Iteration nr. 81
# Iteration nr. 82
# Iteration nr. 83
# Iteration nr. 84
# Iteration nr. 85
# Iteration nr. 86
# Iteration nr. 87
# Iteration nr. 88
# Iteration nr. 89
# Iteration nr. 90
# Iteration nr. 91
# Iteration nr. 92
# Iteration nr. 93
# Iteration nr. 94
# Iteration nr. 95
# Iteration nr. 96
# Iteration nr. 97
# Iteration nr. 98
# Iteration nr. 99
# Iteration nr. 100
# Iteration nr. 101
# Iteration nr. 102
# Iteration nr. 103
# Iteration nr. 104
# Iteration nr. 105
# Iteration nr. 106
# Iteration nr. 107
# Iteration nr. 108
# Iteration nr. 109
# Iteration nr. 110
# Iteration nr. 111
# Iteration nr. 112
# Iteration nr. 113
# Iteration nr. 114
# Iteration nr. 115
# Iteration nr. 116
# Iteration nr. 117
# Iteration nr. 118
# Iteration nr. 119
# Iteration nr. 120
# Iteration nr. 121
# Iteration nr. 122
# Iteration nr. 123
# Iteration nr. 124
# Iteration nr. 125
# Iteration nr. 126
# Iteration nr. 127
# Iteration nr. 128
# Iteration nr. 129
# Iteration nr. 130
# Iteration nr. 131
# Iteration nr. 132
# Iteration nr. 133
# Iteration nr. 134
# Iteration nr. 135
# Iteration nr. 136
# Iteration nr. 137
# Iteration nr. 138
# Iteration nr. 139
# Iteration nr. 140
# Iteration nr. 141
# Iteration nr. 142
# Iteration nr. 143
# Iteration nr. 144
# Iteration nr. 145
# Iteration nr. 146
# Iteration nr. 147
# Iteration nr. 148
# Iteration nr. 149
# Iteration nr. 150
# Iteration nr. 151
# Iteration nr. 152
# Iteration nr. 153
# Iteration nr. 154
# Iteration nr. 155
# Iteration nr. 156
# Iteration nr. 157
# Iteration nr. 158
# Iteration nr. 159
# Iteration nr. 160
# Iteration nr. 161
# Iteration nr. 162
# Iteration nr. 163
# Iteration nr. 164
# Iteration nr. 165
# Iteration nr. 166
# Iteration nr. 167
# Iteration nr. 168
# Iteration nr. 169
# Iteration nr. 170
# Iteration nr. 171
# Iteration nr. 172
# Iteration nr. 173
# Iteration nr. 174
# Iteration nr. 175
# Iteration nr. 176
# Iteration nr. 177
# Iteration nr. 178
# Iteration nr. 179
# Iteration nr. 180
# Iteration nr. 181
# Iteration nr. 182
# Iteration nr. 183
# Iteration nr. 184
# Iteration nr. 185
# Iteration nr. 186
# Iteration nr. 187
# Iteration nr. 188
# Iteration nr. 189
# Iteration nr. 190
# Iteration nr. 191
# Iteration nr. 192
# Iteration nr. 193
# Iteration nr. 194
# Iteration nr. 195
# Iteration nr. 196
# Iteration nr. 197
# Iteration nr. 198
# Iteration nr. 199
# Iteration nr. 200
# Iteration nr. 201
# #_________ Phase =  4.29902152596498 _________#
# Hermition:  True
# Iteration nr. 1
# Iteration nr. 2
# Iteration nr. 3
# Iteration nr. 4
# Iteration nr. 5
# Iteration nr. 6
# Iteration nr. 7
# Iteration nr. 8
# Iteration nr. 9
# Iteration nr. 10
# Iteration nr. 11
# Iteration nr. 12
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-a572059d1958> in <module>()
# ----> 1 current_for_phase, phase_arr = solve_for_sns_system()
#
# ~/Documents/NTNU/GitHub/FysMat/Prosjektoppgave/main.py in solve_for_sns_system(max_num_iter, tol)
#     104
#     105
# --> 106         solve_system(system, max_num_iter, tol)
#     107         current_arr = system.current_along_lattice()
#     108         current_midle[i] = np.imag(current_arr)[system.L_sc_0 + system.L_nc // 2]
#
# ~/Documents/NTNU/GitHub/FysMat/Prosjektoppgave/solve_hamiltonian.py in solve_system(system, max_num_iter, tol)
#      30             # mulig å ta bort set_hamiltionian, og heller ha en if test i update_hamiltonian for å opdater u og initialisere hamiltionian til 0
#      31             for kz_idx in range(1, len(system.kz_array)):
# ---> 32                 system.set_hamiltonian(ky=system.ky_array[ky_idx], kz=system.kz_array[kz_idx])
#      33
#      34                 # Calculates the eigenvalues from hamiltonian.
#
# ~/Documents/NTNU/GitHub/FysMat/Prosjektoppgave/system_class.py in set_hamiltonian(self, ky, kz)
#     401                 self.hamiltonian[4 * i:4 * i + 4, 4 * j:4 * j + 4] = self.set_delta(self.hamiltonian[4 * i:4 * i + 4, 4 * j:4 * j + 4], i, j)
#     402                 self.hamiltonian[4 * i:4 * i + 4, 4 * j:4 * j + 4] = self.set_rashba_ky(self.hamiltonian[4 * i:4 * i + 4, 4 * j:4 * j + 4], i, j, ky, kz)
# --> 403                 self.hamiltonian[4 * i:4 * i + 4, 4 * j:4 * j + 4] = self.set_h(self.hamiltonian[4 * i:4 * i + 4, 4 * j:4 * j + 4], i, j)
#     404         return self
#     405
#
# ~/Documents/NTNU/GitHub/FysMat/Prosjektoppgave/system_class.py in set_h(self, arr, i, j)
#     373         return arr
#     374
# --> 375     def set_h(self, arr, i, j):
#     376     # cdef double complex [:,:] n_dot_sigma = n_dot_sigma(h_i[i,:])
#     377         if i == j:
#
# KeyboardInterrupt:

# %%
# e-4 is not enough, current e-1... need prop tole-5.

# %%
import matplotlib.pyplot as plt
plt.plot(phase_arr, current_for_phase/max(current_for_phase))
plt.xlabel("phase diff (phi)")
plt.ylabel("current I_x/I_c")
plt.title("Supercurrent SNS[5-5-5], TOL E-4 {L_y=20, L_z=20, mu_sc=0.9, mu_nc=0.9,mu_soc=0.85, u_sc=-4.2, beta=100}")
plt.savefig('current_sns_phase_change_5-5-5_tole_4.png', dpi=200, bbox_inches='tight')
plt.show()

# %%
#https://numpy.org/doc/stable/reference/generated/numpy.savez.html
np.savez('sns_5_5_5_L20_u4_2_tole_4.npz', phase_arr, current_for_phase)
#npzfile = np.load(outfile)
#npzfile.files
#['arr_0', 'arr_1']
#npzfile['arr_0']

# %%
npzfile = np.load('sns_4_4_4_L20_u2_2.npz')

# %% [markdown]
# <h2> Given that the current is correct; create plot for current as a function of L (length of Ferromagnet) in SFS-system.

# %%
import sys
from matplotlib import cm
import matplotlib.pyplot as plt
import numpy as np

sys.path.append("/Users/martinedh/Documents/NTNU/GitHub/FysMat/Prosjektoppgave")
from main import solve_for_sfs_system

# %%
current_for_L_f, L_f_arr = solve_for_sfs_system()

# %%
plt.plot(L_f_arr, current_for_L_f)
plt.xlabel("Thickness of ferromagnet [L]")
plt.ylabel("current I_x")
plt.title("Supercurrent SFS[15-L-15], tol e-6 {L_y=60, L_z=60, mu_sc=0.9, mu_nc=0.9,mu_soc=0.85, u_sc=-2.2, h=[0,0,1], beta=100}")
plt.savefig('current_sfs_L_change_hz=1_15_L_15.png', dpi=200, bbox_inches='tight')
plt.show()

# %% [markdown]
# <h2> Given that the current is correct; create plot for current as a function of rashba(alpha) strength in S-HM-S-system.

# %%
import sys
from matplotlib import cm
import matplotlib.pyplot as plt
import numpy as np

sys.path.append("/Users/martinedh/Documents/NTNU/GitHub/FysMat/Prosjektoppgave")
from main import solve_for_shms_system

# %%
current_for_L_hm, L_hm_arr = solve_for_shms_system(xz = True)

# %%
plt.plot(L_hm_arr, current_for_L_hm)
plt.xlabel("strength of alpha n=z")
plt.ylabel("current I_x")
plt.title("Supercurrent S-HM-S[15-2-15], tol e-6 {L_y=50, L_z=50, mu_sc=0.9, mu_nc=0.9,mu_soc=0.85, u_sc=-2.2, alpha=[0,0,strength], beta=100}")
plt.savefig('current_shms_alpha_strength_change_n=z_15_2_15.png', dpi=200, bbox_inches='tight')
plt.show()
