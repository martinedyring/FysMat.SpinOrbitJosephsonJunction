# %%
import sys
from matplotlib import cm
import matplotlib.pyplot as plt
import numpy as np

sys.path.append("/Users/martinedh/Documents/NTNU/GitHub/FysMat/Prosjektoppgave")
from main import solve_and_return_system_and_F_matrix
from main import define_system, solve_and_test_small_system, solve_for_sns_system, solve_for_sfs_system
from plots import plot_pairing_amplitude, plot_density_of_states

from solve_hamiltonian import solve_system

# %% [markdown]
# <h2> Current for one system of SNS. Test to see if current is constant.
# Also: Test for runtime and convergance

# %%
# record runtime
import timeit
start = timeit.default_timer()


system, F_matrix = solve_and_test_small_system()

# print runtime
stop = timeit.default_timer()
print('Time: ', stop - start)
# Out:
# Hermition:  True
# Iteration nr. 1
# delta_diff =  7.02624469438874  -- normalized: delta_diff/L_x =  0.702624469438874
# Iteration nr. 2
# delta_diff =  2.0410830695419295  -- normalized: delta_diff/L_x =  0.20410830695419296
# Iteration nr. 3
# delta_diff =  0.9736034120113628  -- normalized: delta_diff/L_x =  0.09736034120113628
# Iteration nr. 4
# delta_diff =  0.4460213727003294  -- normalized: delta_diff/L_x =  0.04460213727003294
# Iteration nr. 5
# delta_diff =  0.20027963278707234  -- normalized: delta_diff/L_x =  0.020027963278707234
# Iteration nr. 6
# delta_diff =  0.08902727636628124  -- normalized: delta_diff/L_x =  0.008902727636628124
# Iteration nr. 7
# delta_diff =  0.03931953223551196  -- normalized: delta_diff/L_x =  0.003931953223551196
# Iteration nr. 8
# delta_diff =  0.017245799099469408  -- normalized: delta_diff/L_x =  0.0017245799099469407
# Iteration nr. 9
# delta_diff =  0.007476154221131792  -- normalized: delta_diff/L_x =  0.0007476154221131792
# Iteration nr. 10
# delta_diff =  0.0031648165219691094  -- normalized: delta_diff/L_x =  0.0003164816521969109
# Iteration nr. 11
# delta_diff =  0.001270705385129134  -- normalized: delta_diff/L_x =  0.00012707053851291342
# Iteration nr. 12
# delta_diff =  0.0004457948784810567  -- normalized: delta_diff/L_x =  4.457948784810567e-05
# Iteration nr. 13
# delta_diff =  9.304165121568628e-05  -- normalized: delta_diff/L_x =  9.304165121568627e-06
# Iteration nr. 14
# delta_diff =  5.188626089054175e-05  -- normalized: delta_diff/L_x =  5.188626089054175e-06
# Iteration nr. 15
# delta_diff =  0.00010596572206092657  -- normalized: delta_diff/L_x =  1.0596572206092657e-05
# Iteration nr. 16
# delta_diff =  0.00012090933721793441  -- normalized: delta_diff/L_x =  1.209093372179344e-05
# Iteration nr. 17
# delta_diff =  0.0001195211978197215  -- normalized: delta_diff/L_x =  1.1952119781972149e-05
# Iteration nr. 18
# delta_diff =  0.00011180170390723419  -- normalized: delta_diff/L_x =  1.1180170390723418e-05
# Iteration nr. 19
# delta_diff =  0.00010208409661654096  -- normalized: delta_diff/L_x =  1.0208409661654096e-05
# Iteration nr. 20
# delta_diff =  9.219790632839631e-05  -- normalized: delta_diff/L_x =  9.219790632839632e-06
# Iteration nr. 21
# delta_diff =  8.287145776445156e-05  -- normalized: delta_diff/L_x =  8.287145776445155e-06
# Iteration nr. 22
# delta_diff =  7.43534901871162e-05  -- normalized: delta_diff/L_x =  7.43534901871162e-06
# Iteration nr. 23
# delta_diff =  6.668831665188566e-05  -- normalized: delta_diff/L_x =  6.668831665188566e-06
# Iteration nr. 24
# delta_diff =  5.983720189338236e-05  -- normalized: delta_diff/L_x =  5.983720189338236e-06
# Iteration nr. 25
# delta_diff =  5.373147577968491e-05  -- normalized: delta_diff/L_x =  5.373147577968491e-06
# Iteration nr. 26
# delta_diff =  4.829536510684634e-05  -- normalized: delta_diff/L_x =  4.829536510684634e-06
# Iteration nr. 27
# delta_diff =  4.345542611737312e-05  -- normalized: delta_diff/L_x =  4.345542611737312e-06
# Iteration nr. 28
# delta_diff =  3.9144085527372426e-05  -- normalized: delta_diff/L_x =  3.914408552737243e-06
# Iteration nr. 29
# delta_diff =  3.530062865965176e-05  -- normalized: delta_diff/L_x =  3.530062865965176e-06
# Iteration nr. 30
# delta_diff =  3.1871117081803264e-05  -- normalized: delta_diff/L_x =  3.1871117081803266e-06
# Iteration nr. 31
# delta_diff =  2.880789091390028e-05  -- normalized: delta_diff/L_x =  2.880789091390028e-06
# Iteration nr. 32
# delta_diff =  2.606894195234626e-05  -- normalized: delta_diff/L_x =  2.606894195234626e-06
# Iteration nr. 33
# delta_diff =  2.3617279330612586e-05  -- normalized: delta_diff/L_x =  2.3617279330612585e-06
# Iteration nr. 34
# delta_diff =  2.1420336258578983e-05  -- normalized: delta_diff/L_x =  2.142033625857898e-06
# Iteration nr. 35
# delta_diff =  1.944943424805035e-05  -- normalized: delta_diff/L_x =  1.944943424805035e-06
# Iteration nr. 36
# delta_diff =  1.767930725919048e-05  -- normalized: delta_diff/L_x =  1.7679307259190481e-06
# Iteration nr. 37
# delta_diff =  1.608768259011461e-05  -- normalized: delta_diff/L_x =  1.608768259011461e-06
# Iteration nr. 38
# delta_diff =  1.4654913240637723e-05  -- normalized: delta_diff/L_x =  1.4654913240637723e-06
# Iteration nr. 39
# delta_diff =  1.3363656045999258e-05  -- normalized: delta_diff/L_x =  1.3363656045999257e-06
# Iteration nr. 40
# delta_diff =  1.2198590115489322e-05  -- normalized: delta_diff/L_x =  1.2198590115489322e-06
# Iteration nr. 41
# delta_diff =  1.1146170568779576e-05  -- normalized: delta_diff/L_x =  1.1146170568779576e-06
# Iteration nr. 42
# delta_diff =  1.0194413103370082e-05  -- normalized: delta_diff/L_x =  1.0194413103370082e-06
# Iteration nr. 43
# delta_diff =  9.332705486865316e-06  -- normalized: delta_diff/L_x =  9.332705486865316e-07
# Time:  480.97726827600854

# %%
plot_pairing_amplitude(system, system.F_matrix) 
# it 1: diff 80.31784729526646
# it 2: diff 13.608228168595833

# %%
#current = current_along_lattice(system)

# prøv denne og se om du fremdeles får en strøm om går hardt til null i sc
current = system.current_along_lattice()

# %%
site_x = np.linspace(0, system.L_x-1, system.L_x-1)
#plt.plot(site_x, np.real(current), label="real")
plt.plot(site_x[1:], np.imag(current)[1:], label="current")
plt.legend()
plt.xlabel("lattice site [SC-SC]/[5-5]")
plt.ylabel("current I_x")
plt.grid()
plt.savefig('current_sc_100itr_LzLy=60.png', dpi=200, bbox_inches='tight')
plt.show()

# %% [markdown]
# <h2> Given that the current is correct; create plot for current as a function of phase in SNS-system.

# %%
import sys
import numpy as np
sys.path.append("/Users/martinedh/Documents/NTNU/GitHub/FysMat/Prosjektoppgave")
from main import define_system, solve_and_test_small_system, solve_for_sns_system

# %%
current_for_phase, phase_arr = solve_for_sns_system()
# Out:
# #_________ Phase =  0.0 _________#
# Hermition:  True
# Iteration nr. 1

# %%
plt.plot(phase_arr, current_for_phase)
plt.xlabel("phase diff (phi)")
plt.ylabel("current I_x")
plt.title("Supercurrent SNS[15-15-15], TOL E-6 {L_y=50, L_z=50, mu_sc=0.9, mu_nc=0.9,mu_soc=0.85, u_sc=-2.2, beta=100}")
plt.savefig('current_sns_phase_change_15_15_15.png', dpi=200, bbox_inches='tight')
plt.show()

# %% [markdown]
# <h2> Given that the current is correct; create plot for current as a function of L (length of Ferromagnet) in SFS-system.

# %%
import sys
from matplotlib import cm
import matplotlib.pyplot as plt
import numpy as np

sys.path.append("/Users/martinedh/Documents/NTNU/GitHub/FysMat/Prosjektoppgave")
from main import solve_for_sfs_system

# %%
current_for_L_f, L_f_arr = solve_for_sfs_system()

# %%
plt.plot(L_f_arr, current_for_L_f)
plt.xlabel("Thickness of ferromagnet [L]")
plt.ylabel("current I_x")
plt.title("Supercurrent SFS[15-L-15], {L_y=30, L_z=30, mu_sc=0.9, mu_nc=0.9,mu_soc=0.85, u_sc=-4.2, h=[0,1.5,0], beta=100}")
#plt.savefig('current_sfs_L_change_hz=1_5.png', dpi=200, bbox_inches='tight')
plt.show()

# %% [markdown]
# <h2> Given that the current is correct; create plot for current as a function of rashba(alpha) strength in S-HM-S-system.

# %%
import sys
from matplotlib import cm
import matplotlib.pyplot as plt
import numpy as np

sys.path.append("/Users/martinedh/Documents/NTNU/GitHub/FysMat/Prosjektoppgave")
from main import solve_for_shms_system

# %%
current_for_L_hm, L_hm_arr = solve_for_shms_system(xz = True)

# %%
plt.plot(L_hm_arr, current_for_L_hm)
plt.xlabel("strength of alpha n=z")
plt.ylabel("current I_x")
plt.title("Supercurrent S-HM-S[15-2-15], {L_y=30, L_z=30, mu_sc=0.9, mu_nc=0.9,mu_soc=0.85, u_sc=-4.2, alpha=[0,0,strength], beta=100}")
#plt.savefig('current_shms_alpha_strength_change_n=z.png', dpi=200, bbox_inches='tight')
plt.show()
