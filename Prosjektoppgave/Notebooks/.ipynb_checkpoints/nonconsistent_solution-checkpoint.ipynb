# %%
import sys
from matplotlib import cm
import matplotlib.pyplot as plt
import numpy as np

sys.path.append("/Users/martinedh/Documents/NTNU/GitHub/FysMat/Prosjektoppgave")
from nonconsistent_solution import *
from system_class import System

from plots import plot_pairing_amplitude, plot_density_of_states

from current_nonconsistent import current_for_phase_array_nonconsistent, calculate_current_for_phase_of_all_alpha_orientations

# %%
def save_array(x, filename):
    np.savez(filename, x)

# %%
system = System(alpha_R_initial = [0.2, 0.0, 0.2], 
                phase=-np.pi/2, 
                L_y = 30,L_z=30, L_sc_0 = 25, L_sc=25, L_soc=5, 
                mu_sc = 0.9,mu_soc = 0.9, 
                u_sc = -2, 
                beta=33.3, 
                t=1)

# %%
# %%time

system.F_matrix, system.eigenvalues, system.eigenvectors, system.hamiltonian = solve_system_nonconsistent(junction=True,
                                                                                                       L_x=system.L_x,
                                                                                                       L_y=system.L_y,
                                                                                                       L_z=system.L_z,
                                                                                                       L_sc=system.L_sc,
                                                                                                       L_soc=system.L_soc,
                                                                                                       mu_array=system.mu_array,
                                                                                                       h_array=system.h_array,
                                                                                                       U_array=system.U_array,
                                                                                                       F_matrix=system.F_matrix,
                                                                                                       t_x_array=system.t_x_array,
                                                                                                       ky_array=system.ky_array,
                                                                                                       kz_array=system.kz_array,
                                                                                                       alpha_R_x_array=system.alpha_R_x_array,
                                                                                                       alpha_R_y_array=system.alpha_R_y_array,
                                                                                                       beta=system.beta,
                                                                                                       phase=system.phase,
                                                                                                       eigenvalues=system.eigenvalues,
                                                                                                       eigenvectors=system.eigenvectors,
                                                                                                       hamiltonian=system.hamiltonian)
# Out:
# CPU times: user 1min, sys: 1.67 s, total: 1min 2s
# Wall time: 33.9 s

# %%
plot_pairing_amplitude(system, system.F_matrix)

# %%
# %%time 

current = system.current_along_lattice()
# Out:
# CPU times: user 6.85 s, sys: 380 ms, total: 7.23 s
# Wall time: 7.86 s

# %%
site_x = np.linspace(0, system.L_x-1, system.L_x-1)
#plt.plot(site_x, np.real(current), label="real")
plt.plot(site_x[1:], np.real(current)[1:], label="current")
plt.legend()
plt.xlabel("lattice site [SC-SOC-SC]/[25-5-25]")
plt.ylabel("current I_x")
plt.grid()
#plt.savefig('current_soc_nonconsistent_LzLy=30_two_iter_lock_as_endpoint.png', dpi=200, bbox_inches='tight')
plt.show()

# %%
def calculate_current_for_phase_of_all_alpha_orientations_and_save(phase_array=np.linspace(0,2*np.pi,15),
                                                          alpha_max=np.linspace(0,1,10),
                                                          theta=0,
                                                          xz=False,
                                                          yz=False,
                                                          ):

    alpha_array = np.ones((len(alpha_max), 3), dtype=np.float64)
    for i in range(len(alpha_max)):
        alpha_array[i] = alpha_max[i] * alpha_array[i, :]

    if (xz == True):
        alpha_array[:] = alpha_array[:] * np.array([np.sin(theta), 0 * theta, np.cos(theta)])  # xz plane, sin(phi)=0
    if (yz == True):
        alpha_array[:] = alpha_array[:] * np.array([0 * theta, np.sin(theta), np.cos(theta)])  # yz plane, cos(phi)=0
    if ((yz == False) and (xz == False)):
        print("You have to choose orientation of alpha, xz or yz!")
        return

    current_all = np.zeros(shape=(len(phase_array),len(alpha_max)))
    for i in range(len(alpha_array)):
        current_all[:,i], phase_array = current_for_phase_array_nonconsistent(L_y=30,
                                                                      L_z=30,
                                                                      L_sc_0=25,
                                                                      L_soc=5,
                                                                      L_sc=25,
                                                                      L_nc=0,
                                                                      mu_sc=0.9,
                                                                      mu_soc=0.9,
                                                                      t=1,
                                                                      u_sc=-2,
                                                                      beta=33.3,
                                                                      alpha_array=alpha_array[i,:])

    return current_all, alpha_array, phase_array

# %% [markdown]
# <h3> current - phase diagram

# %% [markdown]
# %%time
#
# current_for_phase, phase_arr = current_for_phase_array_nonconsistent(L_y=30,
#                                                                       L_z=30,
#                                                                       L_sc_0=25,
#                                                                       L_soc=5,
#                                                                       L_sc=25,
#                                                                       L_nc=0,
#                                                                       mu_sc=0.9,
#                                                                       mu_soc=0.9,
#                                                                       t=1,
#                                                                       u_sc=-2,
#                                                                       beta=33.3,
#                                                                     alpha_array=np.array([0.3,0.0,0.3]))

# %%
import matplotlib.pyplot as plt

plt.plot(phase_arr, current_for_phase, 'o')
plt.plot(phase_arr, current_for_phase)

# %%
current_all_xz, alpha_array, phase_array = calculate_current_for_phase_of_all_alpha_orientations_and_save(phase_array=np.linspace(0,2*np.pi,15),
                                                          alpha_max=np.linspace(0,1,10),
                                                          theta=0,
                                                          xz=True,
                                                          yz=False,
                                                          )

#current_all_xz, alpha_array, phase_array = calculate_current_for_phase_of_all_alpha_orientations(phase_array=np.linspace(0,2*np.pi,15),
#                                                          alpha_max=np.linspace(0,1,10),
#                                                          theta=0,
#                                                          xz=True,
#                                                          yz=False,
#                                                          )
# Out:
# #_________ Phase =  0.0 _________#
# #_________ Phase =  0.4487989505128276 _________#
# #_________ Phase =  0.8975979010256552 _________#
# #_________ Phase =  1.3463968515384828 _________#
# #_________ Phase =  1.7951958020513104 _________#
# #_________ Phase =  2.243994752564138 _________#
# #_________ Phase =  2.6927937030769655 _________#
# #_________ Phase =  3.141592653589793 _________#
# #_________ Phase =  3.5903916041026207 _________#
# #_________ Phase =  4.039190554615448 _________#
# #_________ Phase =  4.487989505128276 _________#
# #_________ Phase =  4.9367884556411035 _________#
# #_________ Phase =  5.385587406153931 _________#
# #_________ Phase =  5.834386356666759 _________#
# #_________ Phase =  6.283185307179586 _________#
# #_________ Phase =  0.0 _________#
# #_________ Phase =  0.4487989505128276 _________#
# #_________ Phase =  0.8975979010256552 _________#
# #_________ Phase =  1.3463968515384828 _________#
# ...

# %%
np.savez('current_all_xz_test2.npz', current_all_xz, alpha_array, phase_array)

# %%
current_all_xz.shape
# Out:
# (15, 10)

# %%
a=3

# %%
filename = 'tmo'

# %%
filename += " if not {}".format(a)

# %%
filename
# Out:
# 'tmo if not 3'

# %%
alpha_array.shape
# Out:
# (10, 3)

# %%
phase_array.shape
# Out:
# (15,)

# %%
for i in range(alpha_array.shape[0]):
    plt.plot(phase_array, current_all_xz[:,i])
    #plt.show()
