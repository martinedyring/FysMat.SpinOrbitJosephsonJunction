# %%
import sys
from matplotlib import cm
import matplotlib.pyplot as plt
import numpy as np

sys.path.append("/Users/martinedh/Documents/NTNU/GitHub/FysMat/Prosjektoppgave")
from current_selfconsistent import calculate_current_for_phase_of_all_alpha_given_theta_and_phi

# %%
# %%time

current_all, alpha_array, phase_array = calculate_current_for_phase_of_all_alpha_given_theta_and_phi(max_num_iter=1000,
                                                                 tol=1e-4,
                                                                 phase_array=np.linspace(0, 2 * np.pi, 15),
                                                                  alpha_max=np.linspace(0, 1, 10),
                                                                  theta=0,
                                                                  phi=0
                                                                  )
# Out:
# -----Alpha value # 1  of  10  ----- theta= 0  phi= 0  -----------------------
# #_________ Phase =  0.0 _________#
# #_________ Phase =  0.4487989505128276 _________#
# #_________ Phase =  0.8975979010256552 _________#
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/Documents/NTNU/GitHub/FysMat/Prosjektoppgave/current_selfconsistent.py in calculate_current_for_phase_of_all_alpha_given_theta_and_phi(max_num_iter, tol, phase_array, alpha_max, theta, phi)
#     165                                                                                u_sc=-1,
#     166                                                                                beta=33.3,
# --> 167                                                                                alpha_array=alpha_array[i, :])
#     168
#     169     return current_all, alpha_array, phase_array
#
# ...
