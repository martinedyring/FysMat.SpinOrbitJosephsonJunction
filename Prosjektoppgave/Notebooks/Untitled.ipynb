# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.widgets import Slider, Button, RadioButtons


fig = plt.figure()
plt.subplots_adjust(bottom=0.25)                
ax = fig.add_subplot(121, projection='3d')        
X= np.arange(-50,50,2)
Y=np.arange(-50,50,2)
X,Y = np.meshgrid(X,Y)

Z = np.sqrt((X**2+Y**2)/(np.tan(np.pi/120)))            
ax.plot_wireframe(X,Y,Z, rstride=3, cstride=3)         
plt.axis('scaled')

h0=0

ax2 = fig.add_subplot(122, projection='3d') 
Z2 = 0*X+0*Y+h0         

l=ax2.plot_surface(X,Y,Z2,color='red',rstride=2, cstride=2)

axhauteur = plt.axes([0.2, 0.1, 0.65, 0.03])
shauteur = Slider(axhauteur, 'Hauteur', 0.5, 10.0, valinit=h0)

def update(val): 
    h = shauteur.val 
    ax2.clear()
    l=ax2.plot_surface(X,Y,0*X+0*Y+h,color='red',rstride=2, cstride=2)
    ax2.set_zlim(0,10)
    fig.canvas.draw_idle() 
shauteur.on_changed(update)
ax2.set_zlim(0,10)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-1-41bd25dbe83a> in <module>
#      14 Z = np.sqrt((X**2+Y**2)/(np.tan(np.pi/120)))
#      15 ax.plot_wireframe(X,Y,Z, rstride=3, cstride=3)
# ---> 16 plt.axis('scaled')
#      17
#      18 h0=0
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in axis(emit, *args, **kwargs)
#    2459 @_copy_docstring_and_deprecators(Axes.axis)
#    2460 def axis(*args, emit=True, **kwargs):
# -> 2461     return gca().axis(*args, emit=emit, **kwargs)
#    2462
#    2463
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in axis(self, emit, *args, **kwargs)
#    1761                     self.set_aspect('equal', adjustable='datalim')
#    1762                 elif s == 'scaled':
# -> 1763                     self.set_aspect('equal', adjustable='box', anchor='C')
#    1764                     self.set_autoscale_on(False)  # Req. by Mark Bakker
#    1765                 elif s == 'tight':
#
# ~/anaconda3/lib/python3.6/site-packages/mpl_toolkits/mplot3d/axes3d.py in set_aspect(self, aspect, adjustable, anchor, share)
#     322         if aspect != 'auto':
#     323             raise NotImplementedError(
# --> 324                 "Axes3D currently only supports the aspect argument "
#     325                 f"'auto'. You passed in {aspect!r}."
#     326             )
#
# NotImplementedError: Axes3D currently only supports the aspect argument 'auto'. You passed in 'equal'.
